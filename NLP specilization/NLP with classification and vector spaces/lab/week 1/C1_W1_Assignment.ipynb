# %% [markdown]
# # Assignment 1: Logistic Regression
# Welcome to week one of this specialization. You will learn about logistic regression. Concretely, you will be implementing logistic regression for sentiment analysis on tweets. Given a tweet, you will decide if it has a positive sentiment or a negative one. Specifically you will:
#
# * Learn how to extract features for logistic regression given some text
# * Implement logistic regression from scratch
# * Apply logistic regression on a natural language processing task
# * Test using your logistic regression
# * Perform error analysis
#
# We will be using a data set of tweets. Hopefully you will get more than 99% accuracy.
# Run the cell below to load in the packages.

# %% [markdown]
# ## Import functions and data

# %%
# run this cell to import nltk
import nltk
from os import getcwd
import w1_unittest

nltk.download('twitter_samples')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     /home/jovyan/nltk_data...
# [nltk_data]   Unzipping corpora/twitter_samples.zip.
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# ### Imported functions
#
# Download the data needed for this assignment. Check out the [documentation for the twitter_samples dataset](http://www.nltk.org/howto/twitter.html).
#
# * twitter_samples: if you're running this notebook on your local computer, you will need to download it using:
# ```Python
# nltk.download('twitter_samples')
# ```
#
# * stopwords: if you're running this notebook on your local computer, you will need to download it using:
# ```python
# nltk.download('stopwords')
# ```
#
# #### Import some helper functions that we provided in the utils.py file:
# * process_tweet: cleans the text, tokenizes it into separate words, removes stopwords, and converts words to stems.
# * build_freqs: this counts how often a word in the 'corpus' (the entire set of tweets) was associated with a positive label '1' or a negative label '0', then builds the 'freqs' dictionary, where each key is the (word,label) tuple, and the value is the count of its frequency within the corpus of tweets.

# %%
filePath = f"{getcwd()}/../tmp2/"
nltk.data.path.append(filePath)

# %%
import numpy as np
import pandas as pd
from nltk.corpus import twitter_samples 

from utils import process_tweet, build_freqs

# %% [markdown]
# ### Prepare the data
# * The `twitter_samples` contains subsets of five thousand positive_tweets, five thousand negative_tweets, and the full set of 10,000 tweets.
#     * If you used all three datasets, we would introduce duplicates of the positive tweets and negative tweets.
#     * You will select just the five thousand positive tweets and five thousand negative tweets.

# %%
# select the set of positive and negative tweets
all_positive_tweets = twitter_samples.strings('positive_tweets.json')
all_negative_tweets = twitter_samples.strings('negative_tweets.json')

# %%
len(all_positive_tweets),len(all_negative_tweets)
# Out:
# (5000, 5000)

# %%
all_positive_tweets[0]
# Out:
# '#FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)'

# %% [markdown]
# * Train test split: 20% will be in the test set, and 80% in the training set.

# %%
# split the data into two pieces, one for training and one for testing (validation set) 
test_pos = all_positive_tweets[4000:]
train_pos = all_positive_tweets[:4000]
test_neg = all_negative_tweets[4000:]
train_neg = all_negative_tweets[:4000]

train_x = train_pos + train_neg 
test_x = test_pos + test_neg

# %% [markdown]
# * Create the numpy array of positive labels and negative labels.

# %%
# combine positive and negative labels
train_y = np.append(np.ones((len(train_pos), 1)), np.zeros((len(train_neg), 1)), axis=0)
test_y = np.append(np.ones((len(test_pos), 1)), np.zeros((len(test_neg), 1)), axis=0)

# %%
train_y[0]
# Out:
# array([1.])

# %%
# Print the shape train and test sets
print("train_y.shape = " + str(train_y.shape))
print("test_y.shape = " + str(test_y.shape))
# Out:
# train_y.shape = (8000, 1)
# test_y.shape = (2000, 1)

# %% [markdown]
# * Create the frequency dictionary using the imported build_freqs function.
#     * We highly recommend that you open utils.py and read the build_freqs function to understand what it is doing.
#     * To view the file directory, go to the menu and click File->Open.
#
# ```Python
#     for y,tweet in zip(ys, tweets):
#         for word in process_tweet(tweet):
#             pair = (word, y)
#             if pair in freqs:
#                 freqs[pair] += 1
#             else:
#                 freqs[pair] = 1
# ```
# * Notice how the outer for loop goes through each tweet, and the inner for loop steps through each word in a tweet.
# * The 'freqs' dictionary is the frequency dictionary that's being built.
# * The key is the tuple (word, label), such as ("happy",1) or ("happy",0).  The value stored for each key is the count of how many times the word "happy" was associated with a positive label, or how many times "happy" was associated with a negative label.

# %%
# create frequency dictionary
freqs = build_freqs(train_x, train_y)

# check the output
print("type(freqs) = " + str(type(freqs)))
print("len(freqs) = " + str(len(freqs.keys())))
# Out:
# type(freqs) = <class 'dict'>
# len(freqs) = 11436

# %%
a=pd.Series(freqs)
a
# Out:
# followfriday  1.0    23
# top           1.0    30
# engag         1.0     7
# member        1.0    14
# commun        1.0    27
#                      ..
# melon         0.0     1
# useless       0.0     1
# soccer        0.0     1
# interview     0.0     2
# thursday      0.0     1
# Length: 11436, dtype: int64

# %%
freqs
# Out:
# {('followfriday', 1.0): 23,
#  ('top', 1.0): 30,
#  ('engag', 1.0): 7,
#  ('member', 1.0): 14,
#  ('commun', 1.0): 27,
#  ('week', 1.0): 72,
#  (':)', 1.0): 2960,
#  ('hey', 1.0): 60,
#  ('jame', 1.0): 7,
#  ('odd', 1.0): 2,
#  (':/', 1.0): 5,
#  ('pleas', 1.0): 81,
#  ('call', 1.0): 27,
#  ('contact', 1.0): 4,
#  ('centr', 1.0): 1,
#  ('02392441234', 1.0): 1,
#  ('abl', 1.0): 6,
#  ('assist', 1.0): 1,
#  ('mani', 1.0): 28,
#  ('thank', 1.0): 522,
#  ('listen', 1.0): 15,
#  ('last', 1.0): 39,
#  ('night', 1.0): 55,
#  ('bleed', 1.0): 2,
#  ('amaz', 1.0): 41,
#  ('track', 1.0): 5,
#  ('scotland', 1.0): 2,
#  ('congrat', 1.0): 15,
#  ('yeaaah', 1.0): 1,
#  ('yipppi', 1.0): 1,
#  ('accnt', 1.0): 2,
#  ('verifi', 1.0): 2,
#  ('rqst', 1.0): 1,
#  ('succeed', 1.0): 1,
#  ('got', 1.0): 57,
#  ('blue', 1.0): 8,
#  ('tick', 1.0): 1,
#  ('mark', 1.0): 1,
#  ('fb', 1.0): 4,
#  ('profil', 1.0): 2,
#  ('15', 1.0): 4,
#  ('day', 1.0): 187,
#  ('one', 1.0): 92,
#  ('irresist', 1.0): 2,
#  ('flipkartfashionfriday', 1.0): 16,
#  ('like', 1.0): 187,
#  ('keep', 1.0): 55,
#  ('love', 1.0): 336,
#  ('custom', 1.0): 4,
#  ('wait', 1.0): 55,
#  ('long', 1.0): 27,
#  ('hope', 1.0): 115,
#  ('enjoy', 1.0): 61,
#  ('happi', 1.0): 162,
#  ('friday', 1.0): 91,
#  ('lwwf', 1.0): 1,
#  ('second', 1.0): 8,
#  ('thought', 1.0): 21,
#  ('’', 1.0): 17,
#  ('enough', 1.0): 16,
#  ('time', 1.0): 101,
#  ('dd', 1.0): 1,
#  ('new', 1.0): 114,
#  ('short', 1.0): 6,
#  ('enter', 1.0): 9,
#  ('system', 1.0): 2,
#  ('sheep', 1.0): 1,
#  ('must', 1.0): 14,
#  ('buy', 1.0): 10,
#  ('jgh', 1.0): 4,
#  ('go', 1.0): 123,
#  ('bayan', 1.0): 1,
#  (':D', 1.0): 523,
#  ('bye', 1.0): 5,
#  ('act', 1.0): 6,
#  ('mischiev', 1.0): 1,
#  ('etl', 1.0): 1,
#  ('layer', 1.0): 1,
#  ('in-hous', 1.0): 1,
#  ('wareh', 1.0): 1,
#  ('app', 1.0): 12,
#  ('katamari', 1.0): 1,
#  ('well', 1.0): 66,
#  ('…', 1.0): 31,
#  ('name', 1.0): 12,
#  ('impli', 1.0): 1,
#  (':p', 1.0): 104,
#  ('influenc', 1.0): 16,
#  ('big', 1.0): 28,
#  ('...', 1.0): 228,
#  ('juici', 1.0): 3,
#  ('selfi', 1.0): 11,
#  ('follow', 1.0): 385,
#  ('u', 1.0): 204,
#  ('back', 1.0): 139,
#  ('perfect', 1.0): 17,
#  ('alreadi', 1.0): 19,
#  ('know', 1.0): 128,
#  ("what'", 1.0): 14,
#  ('great', 1.0): 135,
#  ('opportun', 1.0): 17,
#  ('junior', 1.0): 2,
#  ('triathlet', 1.0): 1,
#  ('age', 1.0): 2,
#  ('12', 1.0): 5,
#  ('13', 1.0): 5,
#  ('gatorad', 1.0): 1,
#  ('seri', 1.0): 4,
#  ('get', 1.0): 166,
#  ('entri', 1.0): 3,
#  ('lay', 1.0): 3,
#  ('greet', 1.0): 4,
#  ('card', 1.0): 6,
#  ('rang', 1.0): 2,
#  ('print', 1.0): 4,
#  ('today', 1.0): 91,
#  ('job', 1.0): 34,
#  (':-)', 1.0): 552,
#  ("friend'", 1.0): 3,
#  ('lunch', 1.0): 3,
#  ('yummm', 1.0): 1,
#  ('nostalgia', 1.0): 1,
#  ('tb', 1.0): 1,
#  ('ku', 1.0): 1,
#  ('id', 1.0): 8,
#  ('conflict', 1.0): 1,
#  ('help', 1.0): 40,
#  ("here'", 1.0): 20,
#  ('screenshot', 1.0): 2,
#  ('work', 1.0): 89,
#  ('hi', 1.0): 154,
#  ('liv', 1.0): 2,
#  ('hello', 1.0): 49,
#  ('need', 1.0): 62,
#  ('someth', 1.0): 25,
#  ('fm', 1.0): 2,
#  ('twitter', 1.0): 25,
#  ('—', 1.0): 22,
#  ('sure', 1.0): 38,
#  ('thing', 1.0): 48,
#  ('dm', 1.0): 34,
#  ('x', 1.0): 50,
#  ("i'v", 1.0): 25,
#  ('heard', 1.0): 9,
#  ('four', 1.0): 5,
#  ('season', 1.0): 5,
#  ('pretti', 1.0): 17,
#  ('dope', 1.0): 2,
#  ('penthous', 1.0): 1,
#  ('obv', 1.0): 1,
#  ('gobigorgohom', 1.0): 1,
#  ('fun', 1.0): 45,
#  ("y'all", 1.0): 4,
#  ('yeah', 1.0): 30,
#  ('suppos', 1.0): 6,
#  ('lol', 1.0): 48,
#  ('chat', 1.0): 9,
#  ('bit', 1.0): 16,
#  ('youth', 1.0): 14,
#  ('💅', 1.0): 1,
#  ('🏽', 1.0): 1,
#  ('💋', 1.0): 2,
#  ('seen', 1.0): 6,
#  ('year', 1.0): 33,
#  ('rest', 1.0): 9,
#  ('goe', 1.0): 4,
#  ('quickli', 1.0): 3,
#  ('bed', 1.0): 8,
#  ('music', 1.0): 15,
#  ('fix', 1.0): 6,
#  ('dream', 1.0): 17,
#  ('spiritu', 1.0): 1,
#  ('ritual', 1.0): 1,
#  ('festiv', 1.0): 7,
#  ('népal', 1.0): 1,
#  ('begin', 1.0): 4,
#  ('line-up', 1.0): 4,
#  ('left', 1.0): 10,
#  ('see', 1.0): 157,
#  ('sarah', 1.0): 4,
#  ('send', 1.0): 18,
#  ('us', 1.0): 96,
#  ('email', 1.0): 22,
#  ('bitsy@bitdefender.com', 1.0): 1,
#  ("we'll", 1.0): 12,
#  ('asap', 1.0): 5,
#  ('kik', 1.0): 16,
#  ('hatessuc', 1.0): 1,
#  ('32429', 1.0): 1,
#  ('kikm', 1.0): 1,
#  ('lgbt', 1.0): 2,
#  ('tinder', 1.0): 1,
#  ('nsfw', 1.0): 1,
#  ('akua', 1.0): 1,
#  ('cumshot', 1.0): 1,
#  ('come', 1.0): 63,
#  ('hous', 1.0): 5,
#  ('nsn_supplement', 1.0): 1,
#  ('effect', 1.0): 2,
#  ('press', 1.0): 1,
#  ('releas', 1.0): 11,
#  ('distribut', 1.0): 1,
#  ('result', 1.0): 2,
#  ('link', 1.0): 14,
#  ('remov', 1.0): 3,
#  ('pressreleas', 1.0): 1,
#  ('newsdistribut', 1.0): 1,
#  ('bam', 1.0): 44,
#  ('bestfriend', 1.0): 50,
#  ('lot', 1.0): 80,
#  ('warsaw', 1.0): 44,
#  ('<3', 1.0): 119,
#  ('x46', 1.0): 1,
#  ('everyon', 1.0): 45,
#  ('watch', 1.0): 32,
#  ('documentari', 1.0): 1,
#  ('earthl', 1.0): 1,
#  ('youtub', 1.0): 8,
#  ('support', 1.0): 25,
#  ('buuut', 1.0): 1,
#  ('oh', 1.0): 44,
#  ('look', 1.0): 111,
#  ('forward', 1.0): 20,
#  ('visit', 1.0): 25,
#  ('next', 1.0): 37,
#  ('letsgetmessi', 1.0): 1,
#  ('jo', 1.0): 1,
#  ('make', 1.0): 70,
#  ('feel', 1.0): 33,
#  ('better', 1.0): 40,
#  ('never', 1.0): 31,
#  ('anyon', 1.0): 7,
#  ('kpop', 1.0): 1,
#  ('flesh', 1.0): 1,
#  ('good', 1.0): 191,
#  ('girl', 1.0): 34,
#  ('best', 1.0): 49,
#  ('wish', 1.0): 29,
#  ('reason', 1.0): 10,
#  ('epic', 1.0): 1,
#  ('soundtrack', 1.0): 1,
#  ('shout', 1.0): 11,
#  ('ad', 1.0): 10,
#  ('video', 1.0): 30,
#  ('playlist', 1.0): 5,
#  ('im', 1.0): 41,
#  ('twitch', 1.0): 7,
#  ('leagu', 1.0): 6,
#  ('1', 1.0): 63,
#  ('4', 1.0): 23,
#  ('would', 1.0): 70,
#  ('dear', 1.0): 15,
#  ('jordan', 1.0): 1,
#  ('okay', 1.0): 31,
#  ('fake', 1.0): 1,
#  ('gameplay', 1.0): 1,
#  (';)', 1.0): 22,
#  ('haha', 1.0): 44,
#  ('kid', 1.0): 13,
#  ('stuff', 1.0): 11,
#  ('exactli', 1.0): 5,
#  ('product', 1.0): 11,
#  ('line', 1.0): 6,
#  ('etsi', 1.0): 1,
#  ('shop', 1.0): 12,
#  ('check', 1.0): 39,
#  ('boxroomcraft', 1.0): 1,
#  ('vacat', 1.0): 5,
#  ('recharg', 1.0): 1,
#  ('normal', 1.0): 5,
#  ('charger', 1.0): 2,
#  ('asleep', 1.0): 7,
#  ('talk', 1.0): 38,
#  ('sooo', 1.0): 6,
#  ('someon', 1.0): 29,
#  ('text', 1.0): 12,
#  ('ye', 1.0): 60,
#  ('bet', 1.0): 6,
#  ("he'll", 1.0): 2,
#  ('fit', 1.0): 2,
#  ('hear', 1.0): 24,
#  ('speech', 1.0): 1,
#  ('piti', 1.0): 2,
#  ('green', 1.0): 2,
#  ('garden', 1.0): 5,
#  ('midnight', 1.0): 1,
#  ('sun', 1.0): 6,
#  ('beauti', 1.0): 45,
#  ('canal', 1.0): 1,
#  ('dasvidaniya', 1.0): 1,
#  ('till', 1.0): 16,
#  ('scout', 1.0): 1,
#  ('sg', 1.0): 1,
#  ('futur', 1.0): 9,
#  ('wlan', 1.0): 1,
#  ('pro', 1.0): 4,
#  ('confer', 1.0): 1,
#  ('asia', 1.0): 1,
#  ('chang', 1.0): 20,
#  ('lollipop', 1.0): 1,
#  ('🍭', 1.0): 1,
#  ('nez', 1.0): 1,
#  ('agnezmo', 1.0): 1,
#  ('oley', 1.0): 1,
#  ('mama', 1.0): 1,
#  ('stand', 1.0): 6,
#  ('stronger', 1.0): 1,
#  ('god', 1.0): 14,
#  ('misti', 1.0): 1,
#  ('babi', 1.0): 17,
#  ('cute', 1.0): 22,
#  ('woohoo', 1.0): 3,
#  ("can't", 1.0): 31,
#  ('sign', 1.0): 9,
#  ('yet', 1.0): 12,
#  ('still', 1.0): 37,
#  ('think', 1.0): 54,
#  ('mka', 1.0): 5,
#  ('liam', 1.0): 5,
#  ('access', 1.0): 3,
#  ('welcom', 1.0): 54,
#  ('stat', 1.0): 51,
#  ('arriv', 1.0): 57,
#  ('unfollow', 1.0): 53,
#  ('via', 1.0): 73,
#  ('surpris', 1.0): 10,
#  ('figur', 1.0): 5,
#  ('happybirthdayemilybett', 1.0): 1,
#  ('sweet', 1.0): 16,
#  ('talent', 1.0): 4,
#  ('2', 1.0): 41,
#  ('plan', 1.0): 21,
#  ('drain', 1.0): 1,
#  ('gotta', 1.0): 4,
#  ('timezon', 1.0): 1,
#  ('parent', 1.0): 4,
#  ('proud', 1.0): 11,
#  ('least', 1.0): 14,
#  ('mayb', 1.0): 17,
#  ('sometim', 1.0): 11,
#  ('grade', 1.0): 4,
#  ('al', 1.0): 3,
#  ('grand', 1.0): 4,
#  ('manila_bro', 1.0): 1,
#  ('chosen', 1.0): 1,
#  ('let', 1.0): 70,
#  ('around', 1.0): 14,
#  ('..', 1.0): 100,
#  ('side', 1.0): 13,
#  ('world', 1.0): 23,
#  ('eh', 1.0): 2,
#  ('take', 1.0): 30,
#  ('care', 1.0): 12,
#  ('final', 1.0): 24,
#  ('fuck', 1.0): 20,
#  ('weekend', 1.0): 61,
#  ('real', 1.0): 18,
#  ('x45', 1.0): 1,
#  ('join', 1.0): 21,
#  ('hushedcallwithfraydo', 1.0): 1,
#  ('gift', 1.0): 7,
#  ('yeahhh', 1.0): 1,
#  ('hushedpinwithsammi', 1.0): 2,
#  ('event', 1.0): 8,
#  ('might', 1.0): 21,
#  ('luv', 1.0): 4,
#  ('realli', 1.0): 66,
#  ('appreci', 1.0): 28,
#  ('share', 1.0): 41,
#  ('wow', 1.0): 14,
#  ('tom', 1.0): 6,
#  ('3', 1.0): 28,
#  ('gym', 1.0): 3,
#  ('monday', 1.0): 7,
#  ('invit', 1.0): 15,
#  ('scope', 1.0): 5,
#  ('friend', 1.0): 43,
#  ('nude', 1.0): 1,
#  ('sleep', 1.0): 35,
#  ('birthday', 1.0): 53,
#  ('want', 1.0): 71,
#  ('t-shirt', 1.0): 2,
#  ('cool', 1.0): 29,
#  ('haw', 1.0): 1,
#  ('phela', 1.0): 1,
#  ('mom', 1.0): 7,
#  ('obvious', 1.0): 1,
#  ('princ', 1.0): 1,
#  ('charm', 1.0): 1,
#  ('stage', 1.0): 2,
#  ('luck', 1.0): 26,
#  ('tyler', 1.0): 1,
#  ('hipster', 1.0): 1,
#  ('glass', 1.0): 3,
#  ('marti', 1.0): 2,
#  ('glad', 1.0): 41,
#  ('done', 1.0): 40,
#  ('afternoon', 1.0): 7,
#  ('read', 1.0): 28,
#  ('kahfi', 1.0): 1,
#  ('finish', 1.0): 15,
#  ('ohmyg', 1.0): 1,
#  ('yaya', 1.0): 3,
#  ('dub', 1.0): 1,
#  ('stalk', 1.0): 2,
#  ('ig', 1.0): 3,
#  ('gondooo', 1.0): 1,
#  ('moo', 1.0): 2,
#  ('tologooo', 1.0): 1,
#  ('becom', 1.0): 8,
#  ('detail', 1.0): 8,
#  ('zzz', 1.0): 1,
#  ('xx', 1.0): 33,
#  ('physiotherapi', 1.0): 1,
#  ('hashtag', 1.0): 3,
#  ('💪', 1.0): 1,
#  ('monica', 1.0): 1,
#  ('miss', 1.0): 17,
#  ('sound', 1.0): 20,
#  ('morn', 1.0): 68,
#  ("that'", 1.0): 49,
#  ('x43', 1.0): 1,
#  ('definit', 1.0): 20,
#  ('tri', 1.0): 34,
#  ('tonight', 1.0): 15,
#  ('took', 1.0): 7,
#  ('advic', 1.0): 6,
#  ('treviso', 1.0): 1,
#  ('concert', 1.0): 23,
#  ('citi', 1.0): 26,
#  ('countri', 1.0): 22,
#  ("i'll", 1.0): 74,
#  ('start', 1.0): 56,
#  ('fine', 1.0): 7,
#  ('gorgeou', 1.0): 9,
#  ('xo', 1.0): 2,
#  ('oven', 1.0): 2,
#  ('roast', 1.0): 1,
#  ('garlic', 1.0): 1,
#  ('oliv', 1.0): 1,
#  ('oil', 1.0): 4,
#  ('dri', 1.0): 4,
#  ('tomato', 1.0): 1,
#  ('basil', 1.0): 1,
#  ('centuri', 1.0): 1,
#  ('tuna', 1.0): 1,
#  ('right', 1.0): 38,
#  ('atchya', 1.0): 1,
#  ('even', 1.0): 26,
#  ('almost', 1.0): 8,
#  ('chanc', 1.0): 3,
#  ('cheer', 1.0): 18,
#  ('po', 1.0): 3,
#  ('ice', 1.0): 6,
#  ('cream', 1.0): 6,
#  ('agre', 1.0): 13,
#  ('100', 1.0): 6,
#  ('heheheh', 1.0): 2,
#  ('that', 1.0): 10,
#  ('point', 1.0): 11,
#  ('stay', 1.0): 21,
#  ('home', 1.0): 20,
#  ('soon', 1.0): 38,
#  ('promis', 1.0): 4,
#  ('web', 1.0): 4,
#  ('whatsapp', 1.0): 3,
#  ('volta', 1.0): 1,
#  ('funcionar', 1.0): 1,
#  ('com', 1.0): 2,
#  ('iphon', 1.0): 7,
#  ('jailbroken', 1.0): 1,
#  ('later', 1.0): 12,
#  ('34', 1.0): 3,
#  ('min', 1.0): 7,
#  ('leia', 1.0): 1,
#  ('appear', 1.0): 3,
#  ('hologram', 1.0): 1,
#  ('r2d2', 1.0): 1,
#  ('w', 1.0): 16,
#  ('messag', 1.0): 9,
#  ('obi', 1.0): 1,
#  ('wan', 1.0): 1,
#  ('sit', 1.0): 7,
#  ('luke', 1.0): 4,
#  ('inter', 1.0): 1,
#  ('ucl', 1.0): 1,
#  ('arsen', 1.0): 2,
#  ('small', 1.0): 2,
#  ('team', 1.0): 24,
#  ('pass', 1.0): 10,
#  ('🚂', 1.0): 1,
#  ('dewsburi', 1.0): 2,
#  ('railway', 1.0): 1,
#  ('station', 1.0): 4,
#  ('dew', 1.0): 1,
#  ('west', 1.0): 1,
#  ('yorkshir', 1.0): 2,
#  ('430', 1.0): 1,
#  ('smh', 1.0): 2,
#  ('9:25', 1.0): 1,
#  ('live', 1.0): 23,
#  ('strang', 1.0): 4,
#  ('imagin', 1.0): 5,
#  ('megan', 1.0): 1,
#  ('masaantoday', 1.0): 4,
#  ('a4', 1.0): 3,
#  ('shweta', 1.0): 1,
#  ('tripathi', 1.0): 1,
#  ('5', 1.0): 15,
#  ('20', 1.0): 5,
#  ('kurta', 1.0): 3,
#  ('half', 1.0): 6,
#  ('number', 1.0): 11,
#  ('wsalelov', 1.0): 14,
#  ('ah', 1.0): 12,
#  ('larri', 1.0): 3,
#  ('anyway', 1.0): 14,
#  ('kinda', 1.0): 12,
#  ('goood', 1.0): 1,
#  ('life', 1.0): 36,
#  ('enn', 1.0): 1,
#  ('could', 1.0): 25,
#  ('warmup', 1.0): 1,
#  ('15th', 1.0): 2,
#  ('bath', 1.0): 6,
#  ('dum', 1.0): 2,
#  ('andar', 1.0): 1,
#  ('ram', 1.0): 1,
#  ('sampath', 1.0): 1,
#  ('sona', 1.0): 1,
#  ('mohapatra', 1.0): 1,
#  ('samantha', 1.0): 1,
#  ('edward', 1.0): 1,
#  ('mein', 1.0): 1,
#  ('tulan', 1.0): 1,
#  ('razi', 1.0): 2,
#  ('wah', 1.0): 2,
#  ('josh', 1.0): 1,
#  ('alway', 1.0): 48,
#  ('smile', 1.0): 47,
#  ('pictur', 1.0): 7,
#  ('16.20', 1.0): 1,
#  ('giveitup', 1.0): 1,
#  ('given', 1.0): 3,
#  ('ga', 1.0): 3,
#  ('subsidi', 1.0): 1,
#  ('initi', 1.0): 2,
#  ('propos', 1.0): 3,
#  ('delight', 1.0): 4,
#  ('yesterday', 1.0): 4,
#  ('x42', 1.0): 1,
#  ('lmaoo', 1.0): 2,
#  ('song', 1.0): 16,
#  ('ever', 1.0): 19,
#  ('shall', 1.0): 5,
#  ('littl', 1.0): 29,
#  ('throwback', 1.0): 3,
#  ('outli', 1.0): 1,
#  ('island', 1.0): 2,
#  ('cheung', 1.0): 1,
#  ('chau', 1.0): 1,
#  ('mui', 1.0): 1,
#  ('wo', 1.0): 1,
#  ('total', 1.0): 6,
#  ('differ', 1.0): 10,
#  ('kfckitchentour', 1.0): 2,
#  ('kitchen', 1.0): 3,
#  ('clean', 1.0): 1,
#  ("i'm", 1.0): 140,
#  ('cusp', 1.0): 1,
#  ('test', 1.0): 7,
#  ('water', 1.0): 7,
#  ('reward', 1.0): 1,
#  ('arummzz', 1.0): 2,
#  ("let'", 1.0): 20,
#  ('drive', 1.0): 9,
#  ('travel', 1.0): 19,
#  ('yogyakarta', 1.0): 3,
#  ('jeep', 1.0): 3,
#  ('indonesia', 1.0): 3,
#  ('instamood', 1.0): 3,
#  ('wanna', 1.0): 23,
#  ('skype', 1.0): 3,
#  ('may', 1.0): 16,
#  ('nice', 1.0): 71,
#  ('friendli', 1.0): 1,
#  ('pretend', 1.0): 2,
#  ('film', 1.0): 8,
#  ('congratul', 1.0): 9,
#  ('winner', 1.0): 3,
#  ('cheesydelight', 1.0): 1,
#  ('contest', 1.0): 5,
#  ('address', 1.0): 8,
#  ('guy', 1.0): 48,
#  ('market', 1.0): 5,
#  ('24/7', 1.0): 1,
#  ('regret', 1.0): 4,
#  ('14', 1.0): 1,
#  ('hour', 1.0): 24,
#  ('leav', 1.0): 12,
#  ('without', 1.0): 9,
#  ('delay', 1.0): 1,
#  ('actual', 1.0): 13,
#  ('easi', 1.0): 7,
#  ('guess', 1.0): 8,
#  ('train', 1.0): 7,
#  ('wd', 1.0): 1,
#  ('shift', 1.0): 4,
#  ('engin', 1.0): 1,
#  ('etc', 1.0): 2,
#  ('sunburn', 1.0): 1,
#  ('peel', 1.0): 2,
#  ('blog', 1.0): 27,
#  ('huge', 1.0): 9,
#  ('warm', 1.0): 4,
#  ('☆', 1.0): 3,
#  ('complet', 1.0): 10,
#  ('triangl', 1.0): 2,
#  ('northern', 1.0): 1,
#  ('ireland', 1.0): 2,
#  ('sight', 1.0): 1,
#  ('smthng', 1.0): 2,
#  ('fr', 1.0): 3,
#  ('hug', 1.0): 11,
#  ('xoxo', 1.0): 3,
#  ('uu', 1.0): 1,
#  ('jaann', 1.0): 1,
#  ('topnewfollow', 1.0): 2,
#  ('connect', 1.0): 13,
#  ('wonder', 1.0): 26,
#  ('made', 1.0): 38,
#  ('fluffi', 1.0): 1,
#  ('insid', 1.0): 7,
#  ('pirouett', 1.0): 1,
#  ('moos', 1.0): 1,
#  ('trip', 1.0): 12,
#  ('philli', 1.0): 1,
#  ('decemb', 1.0): 2,
#  ("i'd", 1.0): 13,
#  ('dude', 1.0): 6,
#  ('x41', 1.0): 1,
#  ('question', 1.0): 15,
#  ('flaw', 1.0): 1,
#  ('pain', 1.0): 8,
#  ('negat', 1.0): 1,
#  ('strength', 1.0): 2,
#  ('went', 1.0): 10,
#  ('solo', 1.0): 4,
#  ('move', 1.0): 9,
#  ('fav', 1.0): 11,
#  ('nirvana', 1.0): 1,
#  ('smell', 1.0): 2,
#  ('teen', 1.0): 3,
#  ('spirit', 1.0): 1,
#  ('rip', 1.0): 3,
#  ('ami', 1.0): 4,
#  ('winehous', 1.0): 1,
#  ('coupl', 1.0): 5,
#  ('tomhiddleston', 1.0): 1,
#  ('elizabetholsen', 1.0): 1,
#  ('yaytheylookgreat', 1.0): 1,
#  ('goodnight', 1.0): 18,
#  ('vid', 1.0): 8,
#  ('wake', 1.0): 10,
#  ('gonna', 1.0): 16,
#  ('shoot', 1.0): 5,
#  ('itti', 1.0): 2,
#  ('bitti', 1.0): 2,
#  ('teeni', 1.0): 2,
#  ('bikini', 1.0): 3,
#  ('much', 1.0): 73,
#  ('4th', 1.0): 4,
#  ('togeth', 1.0): 6,
#  ('end', 1.0): 13,
#  ('xfile', 1.0): 1,
#  ('content', 1.0): 3,
#  ('rain', 1.0): 18,
#  ('fabul', 1.0): 4,
#  ('fantast', 1.0): 9,
#  ('♡', 1.0): 12,
#  ('jb', 1.0): 1,
#  ('forev', 1.0): 5,
#  ('belieb', 1.0): 3,
#  ('nighti', 1.0): 1,
#  ('bug', 1.0): 2,
#  ('bite', 1.0): 1,
#  ('bracelet', 1.0): 2,
#  ('idea', 1.0): 24,
#  ('foundri', 1.0): 1,
#  ('game', 1.0): 23,
#  ('sens', 1.0): 6,
#  ('pic', 1.0): 21,
#  ('ef', 1.0): 1,
#  ('phone', 1.0): 16,
#  ('woot', 1.0): 2,
#  ('derek', 1.0): 1,
#  ('use', 1.0): 32,
#  ('parkshar', 1.0): 1,
#  ('gloucestershir', 1.0): 1,
#  ('aaaahhh', 1.0): 1,
#  ('man', 1.0): 16,
#  ('traffic', 1.0): 2,
#  ('stress', 1.0): 4,
#  ('reliev', 1.0): 1,
#  ("how'r", 1.0): 1,
#  ('arbeloa', 1.0): 1,
#  ('turn', 1.0): 14,
#  ('17', 1.0): 2,
#  ('omg', 1.0): 13,
#  ('say', 1.0): 43,
#  ('europ', 1.0): 1,
#  ('rise', 1.0): 2,
#  ('find', 1.0): 22,
#  ('hard', 1.0): 9,
#  ('believ', 1.0): 7,
#  ('uncount', 1.0): 1,
#  ('coz', 1.0): 2,
#  ('unlimit', 1.0): 1,
#  ('cours', 1.0): 11,
#  ('teamposit', 1.0): 1,
#  ('aldub', 1.0): 2,
#  ('☕', 1.0): 3,
#  ('rita', 1.0): 2,
#  ('info', 1.0): 11,
#  ("we'd", 1.0): 4,
#  ('way', 1.0): 34,
#  ('boy', 1.0): 13,
#  ('x40', 1.0): 1,
#  ('true', 1.0): 19,
#  ('sethi', 1.0): 2,
#  ('high', 1.0): 6,
#  ('exe', 1.0): 1,
#  ('skeem', 1.0): 1,
#  ('saam', 1.0): 1,
#  ('peopl', 1.0): 43,
#  ('polit', 1.0): 2,
#  ('izzat', 1.0): 1,
#  ('wese', 1.0): 1,
#  ('trust', 1.0): 7,
#  ('khawateen', 1.0): 1,
#  ('k', 1.0): 8,
#  ('sath', 1.0): 2,
#  ('mana', 1.0): 1,
#  ('kar', 1.0): 1,
#  ('deya', 1.0): 1,
#  ('sort', 1.0): 7,
#  ('smart', 1.0): 5,
#  ('hair', 1.0): 7,
#  ('tbh', 1.0): 5,
#  ('jacob', 1.0): 2,
#  ('g', 1.0): 8,
#  ('upgrad', 1.0): 2,
#  ('tee', 1.0): 3,
#  ('famili', 1.0): 14,
#  ('person', 1.0): 14,
#  ('two', 1.0): 15,
#  ('convers', 1.0): 6,
#  ('onlin', 1.0): 4,
#  ('mclaren', 1.0): 1,
#  ('fridayfeel', 1.0): 5,
#  ('tgif', 1.0): 8,
#  ('squar', 1.0): 1,
#  ('enix', 1.0): 1,
#  ('bissmillah', 1.0): 1,
#  ('ya', 1.0): 19,
#  ('allah', 1.0): 3,
#  ("we'r", 1.0): 26,
#  ('socent', 1.0): 1,
#  ('startup', 1.0): 2,
#  ('drop', 1.0): 9,
#  ('your', 1.0): 3,
#  ('arnd', 1.0): 1,
#  ('town', 1.0): 3,
#  ('basic', 1.0): 4,
#  ('piss', 1.0): 2,
#  ('cup', 1.0): 4,
#  ('also', 1.0): 29,
#  ('terribl', 1.0): 2,
#  ('complic', 1.0): 1,
#  ('discuss', 1.0): 2,
#  ('snapchat', 1.0): 31,
#  ('lynettelow', 1.0): 1,
#  ('kikmenow', 1.0): 2,
#  ('snapm', 1.0): 1,
#  ('hot', 1.0): 20,
#  ('amazon', 1.0): 1,
#  ('kikmeguy', 1.0): 2,
#  ('defin', 1.0): 2,
#  ('grow', 1.0): 6,
#  ('sport', 1.0): 4,
#  ('rt', 1.0): 9,
#  ('rakyat', 1.0): 1,
#  ('write', 1.0): 11,
#  ('sinc', 1.0): 11,
#  ('mention', 1.0): 18,
#  ('fli', 1.0): 5,
#  ('fish', 1.0): 4,
#  ('promot', 1.0): 3,
#  ('post', 1.0): 16,
#  ('cyber', 1.0): 1,
#  ('ourdaughtersourprid', 1.0): 3,
#  ('mypapamyprid', 1.0): 2,
#  ('papa', 1.0): 1,
#  ('coach', 1.0): 2,
#  ('posit', 1.0): 3,
#  ('kha', 1.0): 1,
#  ('atleast', 1.0): 2,
#  ('x39', 1.0): 1,
#  ('mango', 1.0): 1,
#  ("lassi'", 1.0): 1,
#  ("monty'", 1.0): 1,
#  ('marvel', 1.0): 2,
#  ('though', 1.0): 16,
#  ('suspect', 1.0): 3,
#  ('meant', 1.0): 2,
#  ('24', 1.0): 3,
#  ('hr', 1.0): 2,
#  ('touch', 1.0): 7,
#  ('kepler', 1.0): 3,
#  ('452b', 1.0): 4,
#  ('chalna', 1.0): 1,
#  ('hai', 1.0): 7,
#  ('thankyou', 1.0): 12,
#  ('hazel', 1.0): 1,
#  ('food', 1.0): 10,
#  ('brooklyn', 1.0): 1,
#  ('pta', 1.0): 2,
#  ('awak', 1.0): 8,
#  ('okayi', 1.0): 2,
#  ('awww', 1.0): 12,
#  ('ha', 1.0): 18,
#  ('doc', 1.0): 1,
#  ('splendid', 1.0): 1,
#  ('spam', 1.0): 1,
#  ('folder', 1.0): 1,
#  ('amount', 1.0): 1,
#  ('nigeria', 1.0): 1,
#  ('claim', 1.0): 1,
#  ('rted', 1.0): 1,
#  ('leg', 1.0): 3,
#  ('hurt', 1.0): 4,
#  ('bad', 1.0): 14,
#  ('mine', 1.0): 11,
#  ('saturday', 1.0): 5,
#  ('thaaank', 1.0): 1,
#  ('puhon', 1.0): 1,
#  ('happinesss', 1.0): 1,
#  ('tnc', 1.0): 1,
#  ('prior', 1.0): 1,
#  ('notif', 1.0): 2,
#  ('probabl', 1.0): 8,
#  ('funni', 1.0): 16,
#  ('2:22', 1.0): 1,
#  ('fat', 1.0): 1,
#  ('co', 1.0): 1,
#  ('ate', 1.0): 4,
#  ('yuna', 1.0): 2,
#  ('tamesid', 1.0): 1,
#  ('´', 1.0): 3,
#  ('googl', 1.0): 5,
#  ('account', 1.0): 17,
#  ('scouser', 1.0): 1,
#  ('everyth', 1.0): 10,
#  ('zoe', 1.0): 1,
#  ('mate', 1.0): 5,
#  ('liter', 1.0): 6,
#  ("they'r", 1.0): 10,
#  ('samee', 1.0): 1,
#  ('edgar', 1.0): 1,
#  ('updat', 1.0): 12,
#  ('log', 1.0): 3,
#  ('bring', 1.0): 14,
#  ('abe', 1.0): 1,
#  ('meet', 1.0): 26,
#  ('x38', 1.0): 1,
#  ('sigh', 1.0): 3,
#  ('dreamili', 1.0): 1,
#  ('pout', 1.0): 1,
#  ('eye', 1.0): 12,
#  ('quacketyquack', 1.0): 6,
#  ('happen', 1.0): 13,
#  ('phil', 1.0): 1,
#  ('em', 1.0): 2,
#  ('del', 1.0): 1,
#  ('rodder', 1.0): 1,
#  ('els', 1.0): 8,
#  ('play', 1.0): 37,
#  ('newest', 1.0): 1,
#  ('gamejam', 1.0): 1,
#  ('irish', 1.0): 2,
#  ('literatur', 1.0): 2,
#  ('inaccess', 1.0): 2,
#  ("kareena'", 1.0): 2,
#  ('fan', 1.0): 21,
#  ('brain', 1.0): 10,
#  ('dot', 1.0): 8,
#  ('braindot', 1.0): 8,
#  ('fair', 1.0): 4,
#  ('rush', 1.0): 1,
#  ('either', 1.0): 10,
#  ('brandi', 1.0): 1,
#  ('18', 1.0): 5,
#  ('carniv', 1.0): 1,
#  ('men', 1.0): 8,
#  ('put', 1.0): 11,
#  ('mask', 1.0): 2,
#  ('xavier', 1.0): 1,
#  ('forneret', 1.0): 1,
#  ('jennif', 1.0): 1,
#  ('site', 1.0): 7,
#  ('free', 1.0): 32,
#  ('50.000', 1.0): 3,
#  ('8', 1.0): 11,
#  ('ball', 1.0): 7,
#  ('pool', 1.0): 5,
#  ('coin', 1.0): 5,
#  ('edit', 1.0): 6,
#  ('trish', 1.0): 1,
#  ('♥', 1.0): 13,
#  ('grate', 1.0): 5,
#  ('three', 1.0): 8,
#  ('comment', 1.0): 8,
#  ('wakeup', 1.0): 1,
#  ('besid', 1.0): 2,
#  ('dirti', 1.0): 2,
#  ('sex', 1.0): 4,
#  ('lmaooo', 1.0): 1,
#  ('😤', 1.0): 2,
#  ('loui', 1.0): 4,
#  ("he'", 1.0): 11,
#  ('throw', 1.0): 3,
#  ('caus', 1.0): 11,
#  ('inspir', 1.0): 6,
#  ('ff', 1.0): 40,
#  ('twoof', 1.0): 3,
#  ('gr8', 1.0): 1,
#  ('wkend', 1.0): 3,
#  ('kind', 1.0): 22,
#  ('exhaust', 1.0): 2,
#  ('word', 1.0): 17,
#  ('cheltenham', 1.0): 1,
#  ('area', 1.0): 4,
#  ('kale', 1.0): 1,
#  ('crisp', 1.0): 1,
#  ('ruin', 1.0): 5,
#  ('x37', 1.0): 1,
#  ('open', 1.0): 12,
#  ('worldwid', 1.0): 2,
#  ('outta', 1.0): 1,
#  ('sfvbeta', 1.0): 1,
#  ('vantast', 1.0): 1,
#  ('xcylin', 1.0): 1,
#  ('bundl', 1.0): 1,
#  ('show', 1.0): 20,
#  ('internet', 1.0): 2,
#  ('price', 1.0): 3,
#  ('realisticli', 1.0): 1,
#  ('pay', 1.0): 8,
#  ('net', 1.0): 1,
#  ('educ', 1.0): 1,
#  ('power', 1.0): 6,
#  ('weapon', 1.0): 1,
#  ('nelson', 1.0): 1,
#  ('mandela', 1.0): 1,
#  ('recent', 1.0): 8,
#  ('j', 1.0): 2,
#  ('chenab', 1.0): 1,
#  ('flow', 1.0): 5,
#  ('pakistan', 1.0): 1,
#  ('incredibleindia', 1.0): 1,
#  ('teenchoic', 1.0): 7,
#  ('choiceinternationalartist', 1.0): 7,
#  ('superjunior', 1.0): 7,
#  ('caught', 1.0): 4,
#  ('first', 1.0): 41,
#  ('salmon', 1.0): 1,
#  ('super-blend', 1.0): 1,
#  ('project', 1.0): 6,
#  ('youth@bipolaruk.org.uk', 1.0): 1,
#  ('awesom', 1.0): 35,
#  ('stream', 1.0): 12,
#  ('artist', 1.0): 2,
#  ('alma', 1.0): 1,
#  ('mater', 1.0): 1,
#  ('highschoolday', 1.0): 1,
#  ('clientvisit', 1.0): 1,
#  ('faith', 1.0): 3,
#  ('christian', 1.0): 1,
#  ('school', 1.0): 9,
#  ('lizaminnelli', 1.0): 1,
#  ('upcom', 1.0): 2,
#  ('uk', 1.0): 4,
#  ('😄', 1.0): 3,
#  ('singl', 1.0): 4,
#  ('hill', 1.0): 4,
#  ('everi', 1.0): 23,
#  ('beat', 1.0): 7,
#  ('wrong', 1.0): 9,
#  ('readi', 1.0): 22,
#  ('natur', 1.0): 1,
#  ...}

# %%
check=[]
for i,v in zip(freqs.keys(), freqs.values()):
    check.append(i[0])
    if i[0]=="kid":
        print(i,v)
a=pd.Series(check)
# Out:
# ('kid', 1.0) 13
# ('kid', 0.0) 16

# %%
a[a.duplicated()]
# Out:
# 5805            tmr
# 5806             :(
# 5807        everyth
# 5808            kid
# 5809        section
#             ...
# 11420    background
# 11429         clear
# 11432       useless
# 11434     interview
# 11435      thursday
# Length: 2271, dtype: object

# %% [markdown]
# #### Expected output
# ```
# type(freqs) = <class 'dict'>
# len(freqs) = 11436
# ```

# %% [markdown]
# ### Process tweet
# The given function 'process_tweet' tokenizes the tweet into individual words, removes stop words and applies stemming.

# %%
# test the function below
print('This is an example of a positive tweet: \n', train_x[0])
print('\nThis is an example of the processed version of the tweet: \n', process_tweet(train_x[0]))
# Out:
# This is an example of a positive tweet:
#  #FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)
#
# This is an example of the processed version of the tweet:
#  ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']

# %% [markdown]
# #### Expected output
# ```
# This is an example of a positive tweet:
#  #FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)
#
# This is an example of the processes version:
#  ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']
# ```

# %% [markdown]
# # Part 1: Logistic regression
#
#
# ### Part 1.1: Sigmoid
# You will learn to use logistic regression for text classification.
# * The sigmoid function is defined as:
#
# $$ h(z) = \frac{1}{1+\exp^{-z}} \tag{1}$$
#
# It maps the input 'z' to a value that ranges between 0 and 1, and so it can be treated as a probability.
#
# <div style="width:image width px; font-size:100%; text-align:center;"><img src='./images/sigmoid_plot.jpg' alt="alternate text" width="width" height="height" style="width:300px;height:200px;" /> Figure 1 </div>

# %% [markdown]
# #### Instructions: Implement the sigmoid function
# * You will want this function to work if z is a scalar as well as if it is an array.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li><a href="https://docs.scipy.org/doc/numpy/reference/generated/numpy.exp.html" > numpy.exp </a> </li>
#
# </ul>
# </p>

# %%
# UNQ_C1 GRADED FUNCTION: sigmoid
def sigmoid(z): 
    '''
    Input:
        z: is the input (can be a scalar or an array)
    Output:
        h: the sigmoid of z
    '''
    
    ### START CODE HERE ###
    # calculate the sigmoid of z
    h = 1/(1+np.exp(-z))
    ### END CODE HERE ###
    
    return h

# %%
# Testing your function 
if (sigmoid(0) == 0.5):
    print('SUCCESS!')
else:
    print('Oops!')

if (sigmoid(4.92) == 0.9927537604041685):
    print('CORRECT!')
else:
    print('Oops again!')
# Out:
# SUCCESS!
# CORRECT!

# %%
# Test your function
w1_unittest.test_sigmoid(sigmoid)
# Out:
#  All tests passed

# %%
# %load '/home/jovyan/work/w1_unittest.py'

# %% [markdown]
# ### Logistic regression: regression and a sigmoid
#
# Logistic regression takes a regular linear regression, and applies a sigmoid to the output of the linear regression.
#
# Regression:
# $$z = \theta_0 x_0 + \theta_1 x_1 + \theta_2 x_2 + ... \theta_N x_N$$
# Note that the $\theta$ values are "weights". If you took the deep learning specialization, we referred to the weights with the 'w' vector.  In this course, we're using a different variable $\theta$ to refer to the weights.
#
# Logistic regression
# $$ h(z) = \frac{1}{1+\exp^{-z}}$$
# $$z = \theta_0 x_0 + \theta_1 x_1 + \theta_2 x_2 + ... \theta_N x_N$$
# We will refer to 'z' as the 'logits'.

# %% [markdown]
# ### Part 1.2 Cost function and Gradient
#
# The cost function used for logistic regression is the average of the log loss across all training examples:
#
# $$J(\theta) = -\frac{1}{m} \sum_{i=1}^m y^{(i)}\log (h(z(\theta)^{(i)})) + (1-y^{(i)})\log (1-h(z(\theta)^{(i)}))\tag{5} $$
# * $m$ is the number of training examples
# * $y^{(i)}$ is the actual label of training example 'i'.
# * $h(z^{(i)})$ is the model's prediction for the training example 'i'.
#
# The loss function for a single training example is
# $$ Loss = -1 \times \left( y^{(i)}\log (h(z(\theta)^{(i)})) + (1-y^{(i)})\log (1-h(z(\theta)^{(i)})) \right)$$
#
# * All the $h$ values are between 0 and 1, so the logs will be negative. That is the reason for the factor of -1 applied to the sum of the two loss terms.
# * Note that when the model predicts 1 ($h(z(\theta)) = 1$) and the label 'y' is also 1, the loss for that training example is 0.
# * Similarly, when the model predicts 0 ($h(z(\theta)) = 0$) and the actual label is also 0, the loss for that training example is 0.
# * However, when the model prediction is close to 1 ($h(z(\theta)) = 0.9999$) and the label is 0, the second term of the log loss becomes a large negative number, which is then multiplied by the overall factor of -1 to convert it to a positive loss value. $-1 \times (1 - 0) \times log(1 - 0.9999) \approx 9.2$ The closer the model prediction gets to 1, the larger the loss.

# %%
# verify that when the model predicts close to 1, but the actual label is 0, the loss is a large positive value
-1 * (1 - 0) * np.log(1 - 0.9999) # loss is about 9.2
# Out:
# 9.210340371976294

# %% [markdown]
# * Likewise, if the model predicts close to 0 ($h(z) = 0.0001$) but the actual label is 1, the first term in the loss function becomes a large number: $-1 \times log(0.0001) \approx 9.2$.  The closer the prediction is to zero, the larger the loss.

# %%
# verify that when the model predicts close to 0 but the actual label is 1, the loss is a large positive value
-1 * np.log(0.0001) # loss is about 9.2
# Out:
# 9.210340371976182

# %% [markdown]
# #### Update the weights
#
# To update your weight vector $\theta$, you will apply gradient descent to iteratively improve your model's predictions.
# The gradient of the cost function $J$ with respect to one of the weights $\theta_j$ is:
#
# $$\nabla_{\theta_j}J(\theta) = \frac{1}{m} \sum_{i=1}^m(h^{(i)}-y^{(i)})x^{(i)}_j \tag{5}$$
# * 'i' is the index across all 'm' training examples.
# * 'j' is the index of the weight $\theta_j$, so $x^{(i)}_j$ is the feature associated with weight $\theta_j$
#
# * To update the weight $\theta_j$, we adjust it by subtracting a fraction of the gradient determined by $\alpha$:
# $$\theta_j = \theta_j - \alpha \times \nabla_{\theta_j}J(\theta) $$
# * The learning rate $\alpha$ is a value that we choose to control how big a single update will be.

# %% [markdown]
# ## Instructions: Implement gradient descent function
# * The number of iterations 'num_iters" is the number of times that you'll use the entire training set.
# * For each iteration, you'll calculate the cost function using all training examples (there are 'm' training examples), and for all features.
# * Instead of updating a single weight $\theta_i$ at a time, we can update all the weights in the column vector:
# $$\mathbf{\theta} = \begin{pmatrix}
# \theta_0
# \\
# \theta_1
# \\
# \theta_2
# \\
# \vdots
# \\
# \theta_n
# \end{pmatrix}$$
# * $\mathbf{\theta}$ has dimensions (n+1, 1), where 'n' is the number of features, and there is one more element for the bias term $\theta_0$ (note that the corresponding feature value $\mathbf{x_0}$ is 1).
# * The 'logits', 'z', are calculated by multiplying the feature matrix 'x' with the weight vector 'theta'.  $z = \mathbf{x}\mathbf{\theta}$
#     * $\mathbf{x}$ has dimensions (m, n+1)
#     * $\mathbf{\theta}$: has dimensions (n+1, 1)
#     * $\mathbf{z}$: has dimensions (m, 1)
# * The prediction 'h', is calculated by applying the sigmoid to each element in 'z': $h(z) = sigmoid(z)$, and has dimensions (m,1).
# * The cost function $J$ is calculated by taking the dot product of the vectors 'y' and 'log(h)'.  Since both 'y' and 'h' are column vectors (m,1), transpose the vector to the left, so that matrix multiplication of a row vector with column vector performs the dot product.
# $$J = \frac{-1}{m} \times \left(\mathbf{y}^T \cdot log(\mathbf{h}) + \mathbf{(1-y)}^T \cdot log(\mathbf{1-h}) \right)$$
# * The update of theta is also vectorized.  Because the dimensions of $\mathbf{x}$ are (m, n+1), and both $\mathbf{h}$ and $\mathbf{y}$ are (m, 1), we need to transpose the $\mathbf{x}$ and place it on the left in order to perform matrix multiplication, which then yields the (n+1, 1) answer we need:
# $$\mathbf{\theta} = \mathbf{\theta} - \frac{\alpha}{m} \times \left( \mathbf{x}^T \cdot \left( \mathbf{h-y} \right) \right)$$

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>use numpy.dot for matrix multiplication.</li>
#     <li>To ensure that the fraction -1/m is a decimal value, cast either the numerator or denominator (or both), like `float(1)`, or write `1.` for the float version of 1. </li>
# </ul>
# </p>

# %%
# UNQ_C2 GRADED FUNCTION: gradientDescent
def gradientDescent(x, y, theta, alpha, num_iters):
    '''
    Input:
        x: matrix of features which is (m,n+1)
        y: corresponding labels of the input matrix x, dimensions (m,1)
        theta: weight vector of dimension (n+1,1)
        alpha: learning rate
        num_iters: number of iterations you want to train your model for
    Output:
        J: the final cost
        theta: your final weight vector
    Hint: you might want to print the cost to make sure that it is going down.
    '''
    ### START CODE HERE ###
    # get 'm', the number of rows in matrix x
    m = x.shape[0]
    
    for i in range(0, num_iters):
        
        # get z, the dot product of x and theta
        z = np.dot(x,theta)

        # get the sigmoid of z
        h = sigmoid(z)

        # calculate the cost function
        J = -(np.dot(y.T, np.log(h)) + np.dot((1-y).T, np.log(1-h)))/m

        # update the weights theta
        theta = theta - alpha * np.dot(x.T, (h-y))/m
        
    ### END CODE HERE ###
    J = float(J)
    return J, theta

# %%
# Check the function
# Construct a synthetic test case using numpy PRNG functions
np.random.seed(1)
# X input is 10 x 3 with ones for the bias terms
tmp_X = np.append(np.ones((10, 1)), np.random.rand(10, 2) * 2000, axis=1)
# Y Labels are 10 x 1
tmp_Y = (np.random.rand(10, 1) > 0.35).astype(float)

# Apply gradient descent
tmp_J, tmp_theta = gradientDescent(tmp_X, tmp_Y, np.zeros((3, 1)), 1e-8, 700)
print(f"The cost after training is {tmp_J:.8f}.")
print(f"The resulting vector of weights is {[round(t, 8) for t in np.squeeze(tmp_theta)]}")
# Out:
# The cost after training is 0.67094970.
# The resulting vector of weights is [4.1e-07, 0.00035658, 7.309e-05]

# %% [markdown]
# #### Expected output
# ```
# The cost after training is 0.67094970.
# The resulting vector of weights is [4.1e-07, 0.00035658, 7.309e-05]
# ```

# %%
# Test your function
w1_unittest.test_gradientDescent(gradientDescent)
# Out:
#  All tests passed

# %% [markdown]
# ## Part 2: Extracting the features
#
# * Given a list of tweets, extract the features and store them in a matrix. You will extract two features.
#     * The first feature is the number of positive words in a tweet.
#     * The second feature is the number of negative words in a tweet.
# * Then train your logistic regression classifier on these features.
# * Test the classifier on a validation set.
#
# ### Instructions: Implement the extract_features function.
# * This function takes in a single tweet.
# * Process the tweet using the imported `process_tweet` function and save the list of tweet words.
# * Loop through each word in the list of processed words
#     * For each word, check the 'freqs' dictionary for the count when that word has a positive '1' label. (Check for the key (word, 1.0)
#     * Do the same for the count for when the word is associated with the negative label '0'. (Check for the key (word, 0.0).)

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>Make sure you handle cases when the (word, label) key is not found in the dictionary. </li>
#     <li> Search the web for hints about using the 'get' function of a Python dictionary.  Here is an <a href="https://www.programiz.com/python-programming/methods/dictionary/get" > example </a> </li>
# </ul>
# </p>

# %%
# UNQ_C3 GRADED FUNCTION: extract_features
def extract_features(tweet, freqs, process_tweet=process_tweet):
    '''
    Input: 
        tweet: a list of words for one tweet
        freqs: a dictionary corresponding to the frequencies of each tuple (word, label)
    Output: 
        x: a feature vector of dimension (1,3)
    '''
    # process_tweet tokenizes, stems, and removes stopwords
    print("tweet:", tweet)
    word_l = process_tweet(tweet)
    print("word_1:",word_l)
    
    # 3 elements in the form of a 1 x 3 vector
    x = np.zeros((1, 3)) 
    
    #bias term is set to 1
    x[0,0] = 1 
    
    ### START CODE HERE ###
    
    # loop through each word in the list of words
    for word in word_l:
        
#         print(word)
        # increment the word count for the positive label 1
#         print("raw:", x)
#         print(freqs.get((word,1),0))
        x[0,1] += freqs.get((word,1),0)
#         print("1st:",x)
#         print(freqs.get((word,0),0))
        # increment the word count for the negative label 0
        x[0,2] += freqs.get((word,0),0)
#         print("2nd:",x)
    ### END CODE HERE ###
    assert(x.shape == (1, 3))
    return x

# %%
len(freqs)
# Out:
# 11436

# %%
# Check your function
# test 1
# test on training data
tmp1 = extract_features(train_x[0], freqs)
print(tmp1)
# Out:
# tweet: #FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)
# word_1: ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']
# followfriday
# raw: [[1. 0. 0.]]
# 23
# 1st: [[ 1. 23.  0.]]
# 0
# 2nd: [[ 1. 23.  0.]]
# top
# raw: [[ 1. 23.  0.]]
# 30
# 1st: [[ 1. 53.  0.]]
# 5
# 2nd: [[ 1. 53.  5.]]
# engag
# raw: [[ 1. 53.  5.]]
# 7
# 1st: [[ 1. 60.  5.]]
# 0
# 2nd: [[ 1. 60.  5.]]
# member
# raw: [[ 1. 60.  5.]]
# 14
# 1st: [[ 1. 74.  5.]]
# 6
# 2nd: [[ 1. 74. 11.]]
# commun
# raw: [[ 1. 74. 11.]]
# 27
# 1st: [[  1. 101.  11.]]
# 1
# 2nd: [[  1. 101.  12.]]
# week
# raw: [[  1. 101.  12.]]
# 72
# 1st: [[  1. 173.  12.]]
# 47
# 2nd: [[  1. 173.  59.]]
# :)
# raw: [[  1. 173.  59.]]
# 2960
# 1st: [[1.000e+00 3.133e+03 5.900e+01]]
# 2
# 2nd: [[1.000e+00 3.133e+03 6.100e+01]]
# [[1.000e+00 3.133e+03 6.100e+01]]

# %% [markdown]
# #### Expected output
# ```
# [[1.000e+00 3.133e+03 6.100e+01]]
# ```

# %%
# test 2:
# check for when the words are not in the freqs dictionary
tmp2 = extract_features('blorb bleeeeb bloooob', freqs)
print(tmp2)
# Out:
# tweet: blorb bleeeeb bloooob
# word_1: ['blorb', 'bleeeb', 'blooob']
# blorb
# raw: [[1. 0. 0.]]
# 0
# 1st: [[1. 0. 0.]]
# 0
# 2nd: [[1. 0. 0.]]
# bleeeb
# raw: [[1. 0. 0.]]
# 0
# 1st: [[1. 0. 0.]]
# 0
# 2nd: [[1. 0. 0.]]
# blooob
# raw: [[1. 0. 0.]]
# 0
# 1st: [[1. 0. 0.]]
# 0
# 2nd: [[1. 0. 0.]]
# [[1. 0. 0.]]

# %% [markdown]
# #### Expected output
# ```
# [[1. 0. 0.]]
# ```

# %%
# Test your function
w1_unittest.test_extract_features(extract_features, freqs)
# Out:
# tweet: #FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)
# word_1: ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']
# followfriday
# raw: [[1. 0. 0.]]
# 23
# 1st: [[ 1. 23.  0.]]
# 0
# 2nd: [[ 1. 23.  0.]]
# top
# raw: [[ 1. 23.  0.]]
# 30
# 1st: [[ 1. 53.  0.]]
# 5
# 2nd: [[ 1. 53.  5.]]
# engag
# raw: [[ 1. 53.  5.]]
# 7
# 1st: [[ 1. 60.  5.]]
# 0
# 2nd: [[ 1. 60.  5.]]
# member
# raw: [[ 1. 60.  5.]]
# 14
# 1st: [[ 1. 74.  5.]]
# 6
# 2nd: [[ 1. 74. 11.]]
# commun
# raw: [[ 1. 74. 11.]]
# 27
# 1st: [[  1. 101.  11.]]
# 1
# 2nd: [[  1. 101.  12.]]
# week
# raw: [[  1. 101.  12.]]
# 72
# 1st: [[  1. 173.  12.]]
# 47
# 2nd: [[  1. 173.  59.]]
# :)
# raw: [[  1. 173.  59.]]
# 2960
# 1st: [[1.000e+00 3.133e+03 5.900e+01]]
# 2
# 2nd: [[1.000e+00 3.133e+03 6.100e+01]]
# tweet: blorb bleeeeb bloooob
# word_1: ['blorb', 'bleeeb', 'blooob']
# blorb
# raw: [[1. 0. 0.]]
# 0
# 1st: [[1. 0. 0.]]
# 0
# 2nd: [[1. 0. 0.]]
# bleeeb
# raw: [[1. 0. 0.]]
# 0
# 1st: [[1. 0. 0.]]
# 0
# 2nd: [[1. 0. 0.]]
# blooob
# raw: [[1. 0. 0.]]
# 0
# 1st: [[1. 0. 0.]]
# 0
# 2nd: [[1. 0. 0.]]
# tweet: Hello world! All's good!
# word_1: ['hello', 'world', "all'", 'good']
# hello
# raw: [[1. 0. 0.]]
# 49
# 1st: [[ 1. 49.  0.]]
# 8
# 2nd: [[ 1. 49.  8.]]
# world
# raw: [[ 1. 49.  8.]]
# 23
# 1st: [[ 1. 72.  8.]]
# 15
# 2nd: [[ 1. 72. 23.]]
# all'
# raw: [[ 1. 72. 23.]]
# 0
# 1st: [[ 1. 72. 23.]]
# 0
# 2nd: [[ 1. 72. 23.]]
# good
# raw: [[ 1. 72. 23.]]
# 191
# 1st: [[  1. 263.  23.]]
# 83
# 2nd: [[  1. 263. 106.]]
# tweet: It is so sad!
# word_1: ['sad']
# sad
# raw: [[1. 0. 0.]]
# 5
# 1st: [[1. 5. 0.]]
# 100
# 2nd: [[  1.   5. 100.]]
#  All tests passed

# %% [markdown]
# ## Part 3: Training Your Model
#
# To train the model:
# * Stack the features for all training examples into a matrix X.
# * Call `gradientDescent`, which you've implemented above.
#
# This section is given to you.  Please read it for understanding and run the cell.

# %%
# collect the features 'x' and stack them into a matrix 'X'
X = np.zeros((len(train_x), 3))
print(X.shape)
for i in range(len(train_x)):
    X[i, :]= extract_features(train_x[i], freqs)

# training labels corresponding to X
Y = train_y

# Apply gradient descent
J, theta = gradientDescent(X, Y, np.zeros((3, 1)), 1e-9, 1500)
print(f"The cost after training is {J:.8f}.")
print(f"The resulting vector of weights is {[round(t, 8) for t in np.squeeze(theta)]}")
# Out:
# (8000, 3)
# tweet: #FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)
# word_1: ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']
# tweet: @Lamb2ja Hey James! How odd :/ Please call our Contact Centre on 02392441234 and we will be able to assist you :) Many thanks!
# word_1: ['hey', 'jame', 'odd', ':/', 'pleas', 'call', 'contact', 'centr', '02392441234', 'abl', 'assist', ':)', 'mani', 'thank']
# tweet: @DespiteOfficial we had a listen last night :) As You Bleed is an amazing track. When are you in Scotland?!
# word_1: ['listen', 'last', 'night', ':)', 'bleed', 'amaz', 'track', 'scotland']
# tweet: @97sides CONGRATS :)
# word_1: ['congrat', ':)']
# tweet: yeaaaah yippppy!!!  my accnt verified rqst has succeed got a blue tick mark on my fb profile :) in 15 days
# word_1: ['yeaaah', 'yipppi', 'accnt', 'verifi', 'rqst', 'succeed', 'got', 'blue', 'tick', 'mark', 'fb', 'profil', ':)', '15', 'day']
# tweet: @BhaktisBanter @PallaviRuhail This one is irresistible :)
# #FlipkartFashionFriday http://t.co/EbZ0L2VENM
# word_1: ['one', 'irresist', ':)', 'flipkartfashionfriday']
# tweet: We don't like to keep our lovely customers waiting for long! We hope you enjoy! Happy Friday! - LWWF :) https://t.co/smyYriipxI
# word_1: ['like', 'keep', 'love', 'custom', 'wait', 'long', 'hope', 'enjoy', 'happi', 'friday', 'lwwf', ':)']
# tweet: @Impatientraider On second thought, there’s just not enough time for a DD :) But new shorts entering system. Sheep must be buying.
# word_1: ['second', 'thought', '’', 'enough', 'time', 'dd', ':)', 'new', 'short', 'enter', 'system', 'sheep', 'must', 'buy']
# tweet: Jgh , but we have to go to Bayan :D bye
# word_1: ['jgh', 'go', 'bayan', ':D', 'bye']
# tweet: As an act of mischievousness, am calling the ETL layer of our in-house warehousing app Katamari.
#
# Well… as the name implies :p.
# word_1: ['act', 'mischiev', 'call', 'etl', 'layer', 'in-hous', 'wareh', 'app', 'katamari', 'well', '…', 'name', 'impli', ':p']
# tweet: #FollowFriday @wncer1 @Defense_gouv for being top influencers in my community this week :)
# word_1: ['followfriday', 'top', 'influenc', 'commun', 'week', ':)']
# tweet: Who Wouldn't Love These Big....Juicy....Selfies :) - http://t.co/QVzjgd1uFo http://t.co/oWBL11eQRY
# word_1: ['love', 'big', '...', 'juici', '...', 'selfi', ':)']
# tweet: @Mish23615351  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)
# word_1: ['follow', 'follow', 'u', 'back', ':)']
# tweet: @jjulieredburn Perfect, so you already know what's waiting for you :)
# word_1: ['perfect', 'alreadi', 'know', "what'", 'wait', ':)']
# tweet: Great new opportunity for junior triathletes aged 12 and 13 at the Gatorade series! Get your entries in :) http://t.co/of3DyOzML0
# word_1: ['great', 'new', 'opportun', 'junior', 'triathlet', 'age', '12', '13', 'gatorad', 'seri', 'get', 'entri', ':)']
# tweet: Laying out a greetings card range for print today - love my job :-)
# word_1: ['lay', 'greet', 'card', 'rang', 'print', 'today', 'love', 'job', ':-)']
# tweet: Friend's lunch... yummmm :)
# #Nostalgia #TBS #KU.
# word_1: ["friend'", 'lunch', '...', 'yummm', ':)', 'nostalgia', 'tb', 'ku']
# tweet: @RookieSenpai @arcadester it is the id conflict thanks for the help :D here's the screenshot of it working
# word_1: ['id', 'conflict', 'thank', 'help', ':D', "here'", 'screenshot', 'work']
# tweet: @oohdawg_ Hi liv :))
# word_1: ['hi', 'liv', ':)']
# tweet: Hello I need to know something can u fm me on Twitter?? — sure thing :) dm me x http://t.co/W6Dy130BV7
# word_1: ['hello', 'need', 'know', 'someth', 'u', 'fm', 'twitter', '—', 'sure', 'thing', ':)', 'dm', 'x']
# tweet: #FollowFriday @MBandScott_ @Eric_FLE @pointsolutions3 for being top new followers in my community this week :)
# word_1: ['followfriday', 'top', 'new', 'follow', 'commun', 'week', ':)']
# tweet: @rossbreadmore I've heard the Four Seasons is pretty dope. Penthouse, obvs #Gobigorgohome
# Have fun y'all :)
# word_1: ["i'v", 'heard', 'four', 'season', 'pretti', 'dope', 'penthous', 'obv', 'gobigorgohom', 'fun', "y'all", ':)']
# tweet: @gculloty87 Yeah I suppose she was lol! Chat in a bit just off out x :))
# word_1: ['yeah', 'suppos', 'lol', 'chat', 'bit', 'x', ':)']
# tweet: Hello :) Get Youth Job Opportunities follow &gt;&gt; @tolajobjobs @maphisa301
# word_1: ['hello', ':)', 'get', 'youth', 'job', 'opportun', 'follow']
# tweet: 💅🏽💋 - :)))) haven't seen you in years
# word_1: ['💅', '🏽', '💋', ':)', 'seen', 'year']
# tweet: @Bosslogic @amellywood @CW_Arrow @ARROWwriters Thank you! :-)
# word_1: ['thank', ':-)']
# tweet: @johngutierrez1 hope the rest of your night goes by quickly... I am off to bed... got my music fix and now it is time to dream  :)
# word_1: ['hope', 'rest', 'night', 'goe', 'quickli', '...', 'bed', '...', 'got', 'music', 'fix', 'time', 'dream', ':)']
# tweet: Spiritual Ritual Festival (Népal)
# Beginning of Line-up :)
# It is left for the line-up (y)
# See more at:... http://t.co/QMNz62OEuc
# word_1: ['spiritu', 'ritual', 'festiv', 'népal', 'begin', 'line-up', ':)', 'left', 'line-up', 'see', '...']
# tweet: @ke7zum Hey Sarah! Send us an email at bitsy@bitdefender.com and we'll help you asap :)
# word_1: ['hey', 'sarah', 'send', 'us', 'email', 'bitsy@bitdefender.com', "we'll", 'help', 'asap', ':)']
# tweet: @izzkamilhalda lols. :D
# word_1: ['lol', ':D']
# tweet: MY kik - hatessuce32429 #kik #kikme #lgbt #tinder #nsfw #akua #cumshot :) http://t.co/TnHJD36yzf
# word_1: ['kik', 'hatessuc', '32429', 'kik', 'kikm', 'lgbt', 'tinder', 'nsfw', 'akua', 'cumshot', ':)']
# tweet: @KalinWhite come to my house :)))))
# word_1: ['come', 'hous', ':)']
# tweet: #nsn_supplements, Effective press release distribution with results! :) [link removed] #PressRelease #NewsDistribution
# word_1: ['nsn_supplement', 'effect', 'press', 'releas', 'distribut', 'result', ':)', 'link', 'remov', 'pressreleas', 'newsdistribut']
# tweet: Hi BAM ! @BarsAndMelody
# Can you follow my bestfriend @969Horan696 ?
# She loves you a lot :)
# See you in Warsaw &lt;3
# Love you &lt;3 x46
# word_1: ['hi', 'bam', 'follow', 'bestfriend', 'love', 'lot', ':)', 'see', 'warsaw', '<3', 'love', '<3', 'x46']
# tweet: everyone watch the documentary Earthlings on YouTube :-)
# word_1: ['everyon', 'watch', 'documentari', 'earthl', 'youtub', ':-)']
# tweet: @jamiefigsxx  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)
# word_1: ['follow', 'follow', 'u', 'back', ':)']
# tweet: #FollowFriday @MichelBauza @InvataOnline for being top supports in my community this week :)
# word_1: ['followfriday', 'top', 'support', 'commun', 'week', ':)']
# tweet: buuuuuuuut oh well :-)
# word_1: ['buuut', 'oh', 'well', ':-)']
# tweet: @leisuremarkltd @NoshandQuaff @aktarislam @keanebrands @HeritageSilver I am looking forward to visiting next week #letsgetmessy Jo :-)
# word_1: ['look', 'forward', 'visit', 'next', 'week', 'letsgetmessi', 'jo', ':-)']
# tweet: @sehunshinedaily if it makes u feel better i never have nor will see anyone in kpop in the flesh :D
# word_1: ['make', 'u', 'feel', 'better', 'never', 'see', 'anyon', 'kpop', 'flesh', ':D']
# tweet: @Joyster2012 @CathStaincliffe Good for you, girl!! Best wishes :-)
# word_1: ['good', 'girl', 'best', 'wish', ':-)']
# tweet: @_Kimimi A great enough reason to listen to one epic soundtrack. :D
# word_1: ['great', 'enough', 'reason', 'listen', 'one', 'epic', 'soundtrack', ':D']
# tweet: @AquaDesignGroup Thank you for the shout out. Have a great Friday :)
# word_1: ['thank', 'shout', 'great', 'friday', ':)']
# tweet: I added a video to a @YouTube playlist http://t.co/yzpfsMxUq0 im back on twitch and today it going to be league :) - 1 / 4
# word_1: ['ad', 'video', 'playlist', 'im', 'back', 'twitch', 'today', 'go', 'leagu', ':)', '1', '4']
# tweet: Would love to see you dear in #Jordan :) waiting you! @FIRDOZ  :) @VisitJordan @dannyprol
# word_1: ['would', 'love', 'see', 'dear', 'jordan', ':)', 'wait', ':)']
# tweet: @ABNORMAL_ANA92 oh, okay :D thanks!
# word_1: ['oh', 'okay', ':D', 'thank']
# tweet: @sssniperwolf like how to fake gameplays ;) haha Im kidding, im kidding. You do good stuff :).
# word_1: ['like', 'fake', 'gameplay', ';)', 'haha', 'im', 'kid', 'im', 'kid', 'good', 'stuff', ':)']
# tweet: @dennislami @Dicle_Aygur, yeah exactly :)
# word_1: ['yeah', 'exactli', ':)']
# tweet: Our new product line is in our #etsy shop now! Check it out :) http://t.co/h8exCTLQxg #boxroomcrafts
# word_1: ['new', 'product', 'line', 'etsi', 'shop', 'check', ':)', 'boxroomcraft']
# tweet: @PeakYourMind I hope your vacation is going great! :D
# word_1: ['hope', 'vacat', 'go', 'great', ':D']
# tweet: @groovinshawn they are rechargeable and it normally comes with a charger when u buy it :)
# word_1: ['recharg', 'normal', 'come', 'charger', 'u', 'buy', ':)']
# tweet: #FollowFriday @France_Espana @reglisse_menthe @CCI_inter for being top engaged members in my community this week :)
# word_1: ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']
# tweet: Well she's asleep and I have no one to talk to sooo someone text me :)
# word_1: ['well', 'asleep', 'one', 'talk', 'sooo', 'someon', 'text', ':)']
# tweet: @brynybrath @smallcappy Yes, I suppose. I bet he'll have a blue fit after hearing her speech today. Pity :-)
# word_1: ['ye', 'suppos', 'bet', "he'll", 'blue', 'fit', 'hear', 'speech', 'today', 'piti', ':-)']
# tweet: Green gardens, midnight sun, beautiful canals dasvidaniya till next visit.:)
# word_1: ['green', 'garden', 'midnight', 'sun', 'beauti', 'canal', 'dasvidaniya', 'till', 'next', 'visit', ':)']
# tweet: @KeithRParsons are you scouting SG for a future WLAN pros conference here in Asia? :)
# word_1: ['scout', 'sg', 'futur', 'wlan', 'pro', 'confer', 'asia', ':)']
# tweet: @Cecilie_Hell @420evilangel @wazimotometal @durooooooo @spigranty Good for u, better change it to lollipop 🍭 :).
# word_1: ['good', 'u', 'better', 'chang', 'lollipop', '🍭', ':)']
# tweet: We &lt;3 u Nez :) #AGNEZMO https://t.co/cGViMHSINz
# word_1: ['<3', 'u', 'nez', ':)', 'agnezmo']
# tweet: @LittleMix Follow me Please :)  This is my Big Dream :)
# word_1: ['follow', 'pleas', ':)', 'big', 'dream', ':)']
# tweet: @Elemaaan  oley be :D
# word_1: ['oley', ':D']
# tweet: "@CowokAddict: Mama is the only reason why I stand stronger up to now! :)"
# word_1: ['mama', 'reason', 'stand', 'stronger', ':)']
# tweet: @MacatangayApril  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)
# word_1: ['follow', 'follow', 'u', 'back', ':)']
# tweet: @tk_kjk_kndr @boukendreamer OH MY GOD MISTY, MY BABY IS SO CUTE!!! :D
# word_1: ['oh', 'god', 'misti', 'babi', 'cute', ':D']
# tweet: @BhaktisBanter
#
# I love blue :)
# #FlipkartFashionFriday http://t.co/HnbinH35ES
# word_1: ['love', 'blue', ':)', 'flipkartfashionfriday']
# tweet: @CarcassDrop Woohoo! Can't wait :) Have you signed up yet, or still thinking about it? MKa
# word_1: ['woohoo', "can't", 'wait', ':)', 'sign', 'yet', 'still', 'think', 'mka']
# tweet: i have liam access now :))
# word_1: ['liam', 'access', ':)']
# tweet: @SyuhxdxTengku most welcome :)
# word_1: ['welcom', ':)']
# tweet: Stats for the day have arrived. 1 new follower and NO unfollowers :) via http://t.co/p6K6SiH58a.
# word_1: ['stat', 'day', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via']
# tweet: @sluttywife2 you shouldn't be surprised...you have an amazing figure :)
# word_1: ['surpris', '...', 'amaz', 'figur', ':)']
# tweet: #FollowFriday @murtishaw @aqui_fr @FRTechStartups for being top influencers in my community this week :)
# word_1: ['followfriday', 'top', 'influenc', 'commun', 'week', ':)']
# tweet: #HappyBirthdayEmilyBett @emilybett :) Wishing you all the best you beautiful,sweet,talented,amazing… https://t.co/humtC1tr3I
# word_1: ['happybirthdayemilybett', ':)', 'wish', 'best', 'beauti', 'sweet', 'talent', 'amaz', '…']
# tweet: 2 plans for the day down the drain great :):
# word_1: ['2', 'plan', 'day', 'drain', 'great', ':)']
# tweet: @x123456789tine @5SOS_FAHUpdates gotta love timezones :p
# word_1: ['gotta', 'love', 'timezon', ':p']
# tweet: are your parents proud of you — lol, not in the least :D maybe sometimes they get happy because of my grades, al... http://t.co/bJjeGIOOGU
# word_1: ['parent', 'proud', '—', 'lol', 'least', ':D', 'mayb', 'sometim', 'get', 'happi', 'grade', 'al', '...']
# tweet: Grande :)  https://t.co/gsaaxNpR8u
# word_1: ['grand', ':)']
# tweet: Manila_bro has chosen to follow me on Twitter! http://t.co/lKXZWXN1fb. Thanks for the follow :)
# word_1: ['manila_bro', 'chosen', 'follow', 'twitter', 'thank', 'follow', ':)']
# tweet: @syazwanzainal sure let me know when you're around..at this side of the world #eh u too take care :-)
# word_1: ['sure', 'let', 'know', 'around', '..', 'side', 'world', 'eh', 'u', 'take', 'care', ':-)']
# tweet: #FollowFriday @michae1green @superninjaalan @Doug_Laney for being top new followers in my community this week :)
# word_1: ['followfriday', 'top', 'new', 'follow', 'commun', 'week', ':)']
# tweet: finally the fucking weekend :)
# word_1: ['final', 'fuck', 'weekend', ':)']
# tweet: REAL :)
# word_1: ['real', ':)']
# tweet: @LoLEsportspedia thanks :D
# word_1: ['thank', ':D']
# tweet: Hi BAM ! @BarsAndMelody
# Can you follow my bestfriend @969Horan696 ?
# She loves you a lot :)
# See you in Warsaw &lt;3
# Love you &lt;3 x45
# word_1: ['hi', 'bam', 'follow', 'bestfriend', 'love', 'lot', ':)', 'see', 'warsaw', '<3', 'love', '<3', 'x45']
# tweet: YES! I Joined #HushedCallWithFraydoe for a call &amp; gift from @_Fraydoe &lt;3 Gotta Get @HushedApp :D http://t.co/VaLVe8omdT
# word_1: ['ye', 'join', 'hushedcallwithfraydo', 'call', 'gift', '<3', 'gotta', 'get', ':D']
# tweet: @YasLarry yeahhh :)
# word_1: ['yeahhh', ':)']
# tweet: can I DM you &amp; make your night better :)))
# word_1: ['dm', 'make', 'night', 'better', ':)']
# tweet: just joined the #HushedPinWithSammy Event :D Might get to Text with @SammyWilk for a day! Luv U @HushedApp http://t.co/kGfgawdHy9
# word_1: ['join', 'hushedpinwithsammi', 'event', ':D', 'might', 'get', 'text', 'day', 'luv', 'u']
# tweet: Would really appreciate it if you share this video around :) https://t.co/MhK3B3wOpQ
# word_1: ['would', 'realli', 'appreci', 'share', 'video', 'around', ':)']
# tweet: Hello :) Get Youth Job Opportunities follow &gt;&gt; @tolajobjobs @xhebenkewu_9920
# word_1: ['hello', ':)', 'get', 'youth', 'job', 'opportun', 'follow']
# tweet: @TomParker oh wow!! That is beautiful tom :)
# word_1: ['oh', 'wow', 'beauti', 'tom', ':)']
# tweet: Love You @darlingIXHAI22 @SyreenAnne :)) https://t.co/wx7yRrE7sV
# word_1: ['love', ':)']
# tweet: I added a video to a @YouTube playlist http://t.co/HVVPhSYakA im back on twitch and today it going to be league :) - 1 / 3
# word_1: ['ad', 'video', 'playlist', 'im', 'back', 'twitch', 'today', 'go', 'leagu', ':)', '1', '3']
# tweet: #FollowFriday @AmericanOGrain @PecomeP @APaulicand for being top supports in my community this week :)
# word_1: ['followfriday', 'top', 'support', 'commun', 'week', ':)']
# tweet: @ZaynZaynmalik30  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)
# word_1: ['follow', 'follow', 'u', 'back', ':)']
# tweet: Gym Monday can't wait :). Likes
# word_1: ['gym', 'monday', "can't", 'wait', ':)', 'like']
# tweet: @HarNiLiZaLouis Hey, here's your invite to join Scope as an influencer :)  http://t.co/rZgZtQ2fJT
# word_1: ['hey', "here'", 'invit', 'join', 'scope', 'influenc', ':)']
# tweet: Those friends know themselves :)
# word_1: ['friend', 'know', ':)']
# tweet: waiting for nudes :-)
# word_1: ['wait', 'nude', ':-)']
# tweet: @JacobWhitesides go sleep u ! :)))))))))
# word_1: ['go', 'sleep', 'u', ':)']
# tweet: Stats for the day have arrived. 1 new follower and NO unfollowers :) via http://t.co/RB8pMNgMEo.
# word_1: ['stat', 'day', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via']
# tweet: My birthday is a week today! :D
# word_1: ['birthday', 'week', 'today', ':D']
# tweet: @metalgear_jp @Kojima_Hideo I want you're T-shirts ! They are so cool ! :D
# word_1: ['want', 't-shirt', 'cool', ':D']
# tweet: @AxeRade haw phela if am not looking like Mom obviously am looking like him :)
# word_1: ['haw', 'phela', 'look', 'like', 'mom', 'obvious', 'look', 'like', ':)']
# tweet: @zaynmalik prince charming on stage :) x https://t.co/OnVFhzt5fZ
# word_1: ['princ', 'charm', 'stage', ':)', 'x']
# tweet: i have really good luck :)
# word_1: ['realli', 'good', 'luck', ':)']
# tweet: Stats for the day have arrived. 1 new follower and NO unfollowers :) via http://t.co/XzsOGaC4zK.
# word_1: ['stat', 'day', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via']
# tweet: #FollowFriday @straz_das @DCarsonCPA @GH813600 for being top engaged members in my community this week :)
# word_1: ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']
# tweet: @twentyonepilots @fujirock_jp tylers hipster glasses :D
# word_1: ['tyler', 'hipster', 'glass', ':D']
# tweet: @MartyRafenstein
#
# Hey Marty !! Glad to see on Twitter. :)
# word_1: ['hey', 'marti', 'glad', 'see', 'twitter', ':)']
# tweet: @UKBusinessLunch Hi we will be joining you again today :)
# word_1: ['hi', 'join', 'today', ':)']
# tweet: @LAfitnessUKhelp done thanks :-)
# word_1: ['done', 'thank', ':-)']
# tweet: Its already afternoon, lets read Al Kahfi before the day finish :)
# word_1: ['alreadi', 'afternoon', 'let', 'read', 'al', 'kahfi', 'day', 'finish', ':)']
# tweet: OhmyG! yaya dub @mainedcm im done doing to stalk your ig accnt.. GONDOOO MOO TOLOGOOO :) HAHA
# word_1: ['ohmyg', 'yaya', 'dub', 'im', 'done', 'stalk', 'ig', 'accnt', '..', 'gondooo', 'moo', 'tologooo', ':)', 'haha']
# tweet: @rozbabes Here's your invite to become a Scope influencer :) Details here: http://t.co/ipJ2yOiGet
# word_1: ["here'", 'invit', 'becom', 'scope', 'influenc', ':)', 'detail']
# tweet: #FollowFriday @NGourd @Locita @D_Robert_Kelly for being top influencers in my community this week :)
# word_1: ['followfriday', 'top', 'influenc', 'commun', 'week', ':)']
# tweet: @kevinthewhippet @Cassie_Spaniel @Bracken_Nelson @BellisimoBella1 @SpanielHarry thanks :) zzz xx
# word_1: ['thank', ':)', 'zzz', 'xx']
# tweet: Physiotherapy Friday is my hashtag for today. Custom! :-)
# word_1: ['physiotherapi', 'friday', 'hashtag', 'today', 'custom', ':-)']
# tweet: @Cjlopez21 you know I will 💪 Monica and I miss you to, yeah sounds good to me :)
# word_1: ['know', '💪', 'monica', 'miss', 'yeah', 'sound', 'good', ':)']
# tweet: "Good morning, beautiful :)" That's all it takes.
# word_1: ['good', 'morn', 'beauti', ':)', "that'", 'take']
# tweet: Hi BAM ! @BarsAndMelody
# Can you follow my bestfriend @969Horan696 ?
# She loves you a lot :)
# See you in Warsaw &lt;3
# Love you &lt;3 x43
# word_1: ['hi', 'bam', 'follow', 'bestfriend', 'love', 'lot', ':)', 'see', 'warsaw', '<3', 'love', '<3', 'x43']
# tweet: @MandaScapinello oh yeah?? I am definitely going to try it tonight then! :) we took your advice too! We are in Treviso now!
# word_1: ['oh', 'yeah', 'definit', 'go', 'tri', 'tonight', ':)', 'took', 'advic', 'treviso']
# tweet: @morallosanthony  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)
# word_1: ['follow', 'follow', 'u', 'back', ':)']
# tweet: @NIKKIERIOZZI Hi! Would you like an @imPastel concert? Let me know your city and country and I'll start working on it! Thanks :)
# word_1: ['hi', 'would', 'like', 'concert', 'let', 'know', 'citi', 'countri', "i'll", 'start', 'work', 'thank', ':)']
# tweet: Fine,
# ...Have a gorgeous Friday, friend!!..; xo..-:)) https://t.co/JmpkZP2DaI
# word_1: ['fine', '...', 'gorgeou', 'friday', 'friend', '..', 'xo', '..', ':)']
# tweet: Oven roasted garlic in olive oil, sun dried tomatoes, some dried basil, and century tuna :) https://t.co/EsCc9QhLob
# word_1: ['oven', 'roast', 'garlic', 'oliv', 'oil', 'sun', 'dri', 'tomato', 'dri', 'basil', 'centuri', 'tuna', ':)']
# tweet: @HostMyOffice @NigelPWhittaker @lemezma @TWBC_Business @_TheBunkerJL Right back atchya!  Have a great day everyone :)
# word_1: ['right', 'back', 'atchya', 'great', 'day', 'everyon', ':)']
# tweet: @TeamTall17 @FlashHayer  but doesn't even follow back :-)
# word_1: ['even', 'follow', 'back', ':-)']
# tweet: The future is almost here then :) https://t.co/rolE3ZCL97
# word_1: ['futur', 'almost', ':)']
# tweet: #FollowFriday @Michelploria @MyFrenchCity @jasoncreation for being top new followers in my community this week :)
# word_1: ['followfriday', 'top', 'new', 'follow', 'commun', 'week', ':)']
# tweet: No chance :)
# word_1: ['chanc', ':)']
# tweet: @ChiAB2486 @MrCliveC @PCDKirkwood @DC_ARVSgt @COPS_President @EmWilliamsCCCU @LauraRGallagher @Hall11Kate @LaMinx541 @JohnTarbet71 cheers :)
# word_1: ['cheer', ':)']
# tweet: @thatguycalledP go po for ice cream :))
# word_1: ['go', 'po', 'ice', 'cream', ':)']
# tweet: @19strawberry66 I agree 100% :)
# word_1: ['agre', '100', ':)']
# tweet: @SpazzyTsukihara hehehehe thats the point :p
# word_1: ['heheheh', 'that', 'point', ':p']
# tweet: @KalinWhite next time just stay home :)
# word_1: ['next', 'time', 'stay', 'home', ':)']
# tweet: @Gculloty87 thanks :)
# word_1: ['thank', ':)']
# tweet: #FollowFriday @digitalplace2be @intlboost @_lafontpresse for being top supports in my community this week :)
# word_1: ['followfriday', 'top', 'support', 'commun', 'week', ':)']
# tweet: @stayfaboo it will be up soon, i promise :)
# word_1: ['soon', 'promis', ':)']
# tweet: Web Whatsapp volta a funcionar com iPhone jailbroken. :-)
# word_1: ['web', 'whatsapp', 'volta', 'funcionar', 'com', 'iphon', 'jailbroken', ':-)']
# tweet: @crustyolddeen (I plan on watching it later) at 34 mins Leia appears as a hologram from R2D2 w a message for Obi Wan as he sits w Luke :)
# word_1: ['plan', 'watch', 'later', '34', 'min', 'leia', 'appear', 'hologram', 'r2d2', 'w', 'messag', 'obi', 'wan', 'sit', 'w', 'luke', ':)']
# tweet: @Mburu__ Inter 3 UCL, Arsenal... Small team, Right! :)
# word_1: ['inter', '3', 'ucl', 'arsen', '...', 'small', 'team', 'right', ':)']
# tweet: Just passing by :) 🚂 (@ Dewsbury Railway Station (DEW) - @nationalrailenq in Dewsbury, West Yorkshire) https://t.co/DvBssHbrfx
# word_1: ['pass', ':)', '🚂', 'dewsburi', 'railway', 'station', 'dew', 'dewsburi', 'west', 'yorkshir']
# tweet: @ClearlyArticle :) its 430 am smh
# word_1: [':)', '430', 'smh']
# tweet: @uptommosass it's 9:25 am here :) I live in Scotland :) it's strange to imagine what?- Megan xx
# word_1: ['9:25', ':)', 'live', 'scotland', ':)', 'strang', 'imagin', 'megan', 'xx']
# tweet: @bookmyshow
#
#  !
# #MasaanToday
# #MasaanToday
#
# A4.... Shweta Tripathi
#  !
# #MasaanToday
# #MasaanToday
#
# -.:-) .-..,
# word_1: ['masaantoday', 'masaantoday', 'a4', '...', 'shweta', 'tripathi', 'masaantoday', 'masaantoday', ':-)', '..']
# tweet: @WforWoman 5. Over 20 W kurtas! And my Mom has about half the number I have :D #WSaleLove
# word_1: ['5', '20', 'w', 'kurta', 'mom', 'half', 'number', ':D', 'wsalelov']
# tweet: Ah! Hello back Larry! @TransworldBooks :) https://t.co/8XhjJb4jtH
# word_1: ['ah', 'hello', 'back', 'larri', ':)']
# tweet: Anyway my Friday is looking kinda gooood :)
# word_1: ['anyway', 'friday', 'look', 'kinda', 'goood', ':)']
# tweet: @jhun_hunyo  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)
# word_1: ['follow', 'follow', 'u', 'back', ':)']
# tweet: Lol. Well. That's life :) thank God it enn you  https://t.co/GLoCEIjGQQ
# word_1: ['lol', 'well', "that'", 'life', ':)', 'thank', 'god', 'enn']
# tweet: @OJBJ @holmesjsamuel surely this could be your warmup this morning ??? Coming on 15th to Bath :) xx
# word_1: ['sure', 'could', 'warmup', 'morn', 'come', '15th', 'bath', ':)', 'xx']
# tweet: Dum Dum Andar - Ram Sampath, Sona Mohapatra &amp; Samantha Edwards Mein Tulane to razi razi, Wah! That's Josh :) http://t.co/ul8MARDfhm
# word_1: ['dum', 'dum', 'andar', 'ram', 'sampath', 'sona', 'mohapatra', 'samantha', 'edward', 'mein', 'tulan', 'razi', 'razi', 'wah', "that'", 'josh', ':)']
# tweet: @justinbieber :) always smile
# word_1: [':)', 'alway', 'smile']
# tweet: @darlakim_ picture. :)
# word_1: ['pictur', ':)']
# tweet: @arsenalnewsasit Thanks again, your time 16.20 right? That's perfect timing for me here :).
# word_1: ['thank', 'time', '16.20', 'right', "that'", 'perfect', 'time', ':)']
# tweet: #FollowFriday @IzywayLesExpats @na4innov @InXpressCoAzur for being top engaged members in my community this week :)
# word_1: ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']
# tweet: @Juleeyaanaa i know :))
# word_1: ['know', ':)']
# tweet: #GiveItUp We have already given up our gas subsidy long back when this initiative was proposed.. Feeling so delighted having done that!! :)
# word_1: ['giveitup', 'alreadi', 'given', 'ga', 'subsidi', 'long', 'back', 'initi', 'propos', '..', 'feel', 'delight', 'done', ':)']
# tweet: @dayloladay I missed this yesterday!! :-)
# word_1: ['miss', 'yesterday', ':-)']
# tweet: Hi BAM ! @BarsAndMelody
# Can you follow my bestfriend @969Horan696 ?
# She loves you a lot :)
# See you in Warsaw &lt;3
# Love you &lt;3 x42
# word_1: ['hi', 'bam', 'follow', 'bestfriend', 'love', 'lot', ':)', 'see', 'warsaw', '<3', 'love', '<3', 'x42']
# tweet: @jaimeemelanie_ lmaoo! The best songs ever &lt;3 We shall have our own little throwback this week (y) :p
# word_1: ['lmaoo', 'best', 'song', 'ever', '<3', 'shall', 'littl', 'throwback', 'week', ':p']
# tweet: @Clazziebritchas then go to the outlying islands, such as Cheung Chau, Mui Wo....totally different :))
# word_1: ['go', 'outli', 'island', 'cheung', 'chau', 'mui', 'wo', '...', 'total', 'differ', ':)']
# tweet: #KFCkitchentours Kitchen is so clean. I'm totally amazed :) @KFC_India
# word_1: ['kfckitchentour', 'kitchen', 'clean', "i'm", 'total', 'amaz', ':)']
# tweet: @cybelxxx  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)
# word_1: ['follow', 'follow', 'u', 'back', ':)']
# tweet: @Jana7380 on the cusp of testing the waters, hope yours is rewarding :)
# word_1: ['cusp', 'test', 'water', 'hope', 'reward', ':)']
# tweet: #FollowFriday @BroadcastBeat @InSunWeTrust @conseilsmkg for being top influencers in my community this week :)
# word_1: ['followfriday', 'top', 'influenc', 'commun', 'week', ':)']
# tweet: arummzz: Let's go... I'll drive for you :p
#
# #traveling #traveler #yogyakarta #jeep #Indonesia #instamood… https://t.co/s7y4Ys5JeU
# word_1: ['arummzz', "let'", 'go', '...', "i'll", 'drive', ':p', 'travel', 'travel', 'yogyakarta', 'jeep', 'indonesia', 'instamood', '…']
# tweet: Anyone wanna skype me? :D
# word_1: ['anyon', 'wanna', 'skype', ':D']
# tweet: @agylyxa may i look so, bit i am a real nice friendly girl :-)
# word_1: ['may', 'look', 'bit', 'real', 'nice', 'friendli', 'girl', ':-)']
# tweet: Im not like them. But i can pretend~ :)
# word_1: ['im', 'like', 'pretend', ':)']
# tweet: watching where we are concert film :)
# word_1: ['watch', 'concert', 'film', ':)']
# tweet: Congratulations @amisharanka95, you're the winner to our #CheesyDelights contest :)
# Please DM us your address and contact number!
# word_1: ['congratul', 'winner', 'cheesydelight', 'contest', ':)', 'pleas', 'dm', 'us', 'address', 'contact', 'number']
# tweet: :) Have a great weekend guys! https://t.co/DLDKLpeTAb
# word_1: [':)', 'great', 'weekend', 'guy']
# tweet: #FollowFriday @CLARAROJASG @BF_P2C @MyBusiness_Plan for being top new followers in my community this week :)
# word_1: ['followfriday', 'top', 'new', 'follow', 'commun', 'week', ':)']
# tweet: @PuaMagasiva it was cool seeing you film today! :)
# word_1: ['cool', 'see', 'film', 'today', ':)']
# tweet: Check out Email Marketing 24/7:  http://t.co/O5fjR7oEqk you won't regret if you buy it :)
# word_1: ['check', 'email', 'market', '24/7', 'regret', 'buy', ':)']
# tweet: @vineshpomal LOL. Come join us ... See u in around 14 hours if u leave now, without delays. :)
# word_1: ['lol', 'come', 'join', 'us', '...', 'see', 'u', 'around', '14', 'hour', 'u', 'leav', 'without', 'delay', ':)']
# tweet: Actually very easy doing like this, it must be a station I guess where the train 'wd take at least an hour for shifting its engine etc :-)
# word_1: ['actual', 'easi', 'like', 'must', 'station', 'guess', 'train', 'wd', 'take', 'least', 'hour', 'shift', 'engin', 'etc', ':-)']
# tweet: sunburn is peeling :-)
# word_1: ['sunburn', 'peel', ':-)']
# tweet: @Sexdate_gratis Visit my blog http://t.co/UzOAqroWKx thanks :D
# word_1: ['visit', 'blog', 'thank', ':D']
# tweet: @TikoSD Hi! Would you like an @imPastel concert? Let me know your city and country and I'll start working on it! Thanks :)
# word_1: ['hi', 'would', 'like', 'concert', 'let', 'know', 'citi', 'countri', "i'll", 'start', 'work', 'thank', ':)']
# tweet: @no1_razorstan then talk to me. I can help you :)
# word_1: ['talk', 'help', ':)']
# tweet: "@CassTheTrainer: A Huge &amp; Warm Welcome to @VodkaBlond :-))"
#
# ☆ finally we complete the triangle ! ☆
# word_1: ['huge', 'warm', 'welcom', ':-)', '☆', 'final', 'complet', 'triangl', '☆']
# tweet: @LucienneDiver I live in Northern Ireland. :) what sights have you seen?
# word_1: ['live', 'northern', 'ireland', ':)', 'sight', 'seen']
# tweet: @Mecastor01Mica  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)
# word_1: ['follow', 'follow', 'u', 'back', ':)']
# tweet: #FollowFriday @Z_Intl_Agency @Tivipro @compexly for being top supports in my community this week :)
# word_1: ['followfriday', 'top', 'support', 'commun', 'week', ':)']
# tweet: Stats for the day have arrived. 1 new follower and NO unfollowers :) via http://t.co/6prugvmOuC.
# word_1: ['stat', 'day', 'arriv', '1', 'new', 'follow', 'unfollow', ':)', 'via']
# tweet: @imraina feeling smthng smthng fr u...lol...wanna hug u....XOXO...love uu jaann take care :* :)) &lt;3 :")
# word_1: ['feel', 'smthng', 'smthng', 'fr', 'u', '...', 'lol', '...', 'wanna', 'hug', 'u', '...', 'xoxo', '...', 'love', 'uu', 'jaann', 'take', 'care', ':)', '<3']
# tweet: thanks mom :)
# word_1: ['thank', 'mom', ':)']
# tweet: Thanks #TopNewFollowers @BestOfFicPad @MrCFluegel @JeanMarcPN Happy to connect :)
# word_1: ['thank', 'topnewfollow', 'happi', 'connect', ':)']
# tweet: @MooseAllain @MeatBingo that is the just most wonderful thing, it's made me feel all fluffy inside. Great pirouette, Moose :D
# word_1: ['wonder', 'thing', 'made', 'feel', 'fluffi', 'insid', 'great', 'pirouett', 'moos', ':D']
# tweet: @KristophCajon I have a trip to philly in December so after that :) I'd love to come out there dude.
# word_1: ['trip', 'philli', 'decemb', ':)', "i'd", 'love', 'come', 'dude']
# tweet: Hi BAM ! @BarsAndMelody
# Can you follow my bestfriend @969Horan696 ?
# She loves you a lot :)
# See you in Warsaw &lt;3
# Love you &lt;3 x41
# word_1: ['hi', 'bam', 'follow', 'bestfriend', 'love', 'lot', ':)', 'see', 'warsaw', '<3', 'love', '<3', 'x41']
# tweet: The question is flawed. Pain doesn't negate strength :)  https://t.co/77TbkS2Djw
# word_1: ['question', 'flaw', 'pain', 'negat', 'strength', ':)']
# tweet: @ReflectKnives You went solo because these moves weren't being made :D
# word_1: ['went', 'solo', 'move', 'made', ':D']
# tweet: hey my fav nirvana song is smells like teen spirit rip amy winehouse :-)))))
# word_1: ['hey', 'fav', 'nirvana', 'song', 'smell', 'like', 'teen', 'spirit', 'rip', 'ami', 'winehous', ':-)']
# tweet: #FollowFriday @CCIdeLYON @CCI_95 @CPNERI_ESIGROUP for being top engaged members in my community this week :)
# word_1: ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']
# tweet: Let's go... I'll drive for you :p
#
# #traveling #traveler #yogyakarta #jeep #Indonesia #instamood… https://t.co/s7y4Ys5JeU
# word_1: ["let'", 'go', '...', "i'll", 'drive', ':p', 'travel', 'travel', 'yogyakarta', 'jeep', 'indonesia', 'instamood', '…']
# tweet: did we name the couple yet?? #TomHiddleston #ElizabethOlsen ?? #yaytheylookgreat :))
# word_1: ['name', 'coupl', 'yet', 'tomhiddleston', 'elizabetholsen', 'yaytheylookgreat', ':)']
# tweet: I love you all goodnight. Vid going up when I wake up you all with love this one :)
# word_1: ['love', 'goodnight', 'vid', 'go', 'wake', 'love', 'one', ':)']
# tweet: This weekend I am gonna shoot the lovely @NarakuBrock again &lt;3! Here a picture I made of her last time :D http://t.co/s3e2dmpt24
# word_1: ['weekend', 'gonna', 'shoot', 'love', '<3', 'pictur', 'made', 'last', 'time', ':D']
# tweet: anyway :-)
# word_1: ['anyway', ':-)']
# tweet: Itty Bitty Teenie Bikini  :) http://t.co/A2oxW0ZI3g http://t.co/jn7KSfHwRc
# word_1: ['itti', 'bitti', 'teeni', 'bikini', ':)']
# tweet: I just joined the #HushedPinWithSammy Event :D Might get to Text with @SammyWilk for a day! Luv U @HushedApp http://t.co/czdow1i44W
# word_1: ['join', 'hushedpinwithsammi', 'event', ':D', 'might', 'get', 'text', 'day', 'luv', 'u']
# tweet: Always so much fun when 4th hour gets together. :)
#
# Ending the night with ice cream and Xfiles.
#
# Content.
# word_1: ['alway', 'much', 'fun', '4th', 'hour', 'get', 'togeth', ':)', 'end', 'night', 'ice', 'cream', 'xfile', 'content']
# tweet: @aangelayap easy :D
# word_1: ['easi', ':D']
# tweet: @NTtownend yes, be surprised if we don't see a bit of rain today... :)
# word_1: ['ye', 'surpris', 'see', 'bit', 'rain', 'today', '...', ':)']
# tweet: @ReyesFraulein  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)
# word_1: ['follow', 'follow', 'u', 'back', ':)']
# tweet: To all @fatpunkstudio have a fabulous Friday and keep up the fantastic work!! :))
# word_1: ['fabul', 'friday', 'keep', 'fantast', 'work', ':)']
# tweet: @justinbieber can you please follow me @caitecat1209 ♡♡♡♡ please jb follow me I love you always and forever. I'm a belieber ♡♡♡♡ :) I love u
# word_1: ['pleas', 'follow', '♡', '♡', '♡', 'pleas', 'jb', 'follow', 'love', 'alway', 'forev', "i'm", 'belieb', '♡', '♡', '♡', ':)', 'love', 'u']
# tweet: #FollowFriday @DiploMix @CCI_entreprises @CCI_92 for being top influencers in my community this week :)
# word_1: ['followfriday', 'top', 'influenc', 'commun', 'week', ':)']
# tweet: Morning all! :)
# word_1: ['morn', ':)']
# tweet: @FranchiSeedsUK good to hear :)
# word_1: ['good', 'hear', ':)']
# tweet: @LusciousLyndee1 Nighty night! Don't let the bed bugs bite :D
# word_1: ['nighti', 'night', 'let', 'bed', 'bug', 'bite', ':D']
# tweet: @Bonsplansblog Very beautiful this bracelet! good idea :)
# word_1: ['beauti', 'bracelet', 'good', 'idea', ':)']
# tweet: @guywilliamsguy waiting for you at the foundry. Where you at?? :)
# word_1: ['wait', 'foundri', ':)']
# tweet: @KalinWhite I like that game :)
# word_1: ['like', 'game', ':)']
# tweet: @suzannepanter @kevinbacon @katosman Ah! Now it makes sense... Didn't see the pic on my effing phone last night. Woot :) x
# word_1: ['ah', 'make', 'sens', '...', 'see', 'pic', 'ef', 'phone', 'last', 'night', 'woot', ':)', 'x']
# tweet: @Derek_GTA Hi Derek, you could try using ParkShare in Gloucestershire http://t.co/qIF9AyAlkc :)
# word_1: ['hi', 'derek', 'could', 'tri', 'use', 'parkshar', 'gloucestershir', ':)']
# tweet: Aaaahhh man, this track is a traffic stress reliever. :)
# word_1: ['aaaahhh', 'man', 'track', 'traffic', 'stress', 'reliev', ':)']
# tweet: #FollowFriday @elevents2 @JoussotFrench_J @NYIBF for being top new followers in my community this week :)
# word_1: ['followfriday', 'top', 'new', 'follow', 'commun', 'week', ':)']
# tweet: @El1neW How're you today my dear? :)
# word_1: ["how'r", 'today', 'dear', ':)']
# tweet: @Jesutomisin I hear you guys want Arbeloa. :D
# word_1: ['hear', 'guy', 'want', 'arbeloa', ':D']
# tweet: @ShawnMendes turning 17 in 15 days...omg. at least we have only 3 years difference :)
# word_1: ['turn', '17', '15', 'day', '...', 'omg', 'least', '3', 'year', 'differ', ':)']
# tweet: @matteomeacci Well, they say Europe is on the rise again, but I find that hard to believe :)
# word_1: ['well', 'say', 'europ', 'rise', 'find', 'hard', 'believ', ':)']
# tweet: @WforWoman #WSaleLove uncountable coz we love unlimited :)
# word_1: ['wsalelov', 'uncount', 'coz', 'love', 'unlimit', ':)']
# tweet: Yes, of course :) #TeamPositive https://t.co/SaIX1VpFJF
# word_1: ['ye', 'cours', ':)', 'teamposit']
# tweet: yes i love :-) #AlDub
# word_1: ['ye', 'love', ':-)', 'aldub']
# tweet: @coffeebreak22 @LauRenArren @drparkave @JWKanyuira1969 @dheracing @RhoaChri @BarbaraBathurst @1cryingeye @willisteam :) ☕☕☕ Thank you Rita!
# word_1: [':)', '☕', '☕', '☕', 'thank', 'rita']
# tweet: @mikerobb Hi there, could you please DM us further info and we'd be happy to help! :)
# word_1: ['hi', 'could', 'pleas', 'dm', 'us', 'info', "we'd", 'happi', 'help', ':)']
# tweet: @24gooch on way my boy! :)
# word_1: ['way', 'boy', ':)']
# tweet: @graphure I hope you will get a lot of nice gifts :D
# word_1: ['hope', 'get', 'lot', 'nice', 'gift', ':D']
# tweet: Hi BAM ! @BarsAndMelody
# Can you follow my bestfriend @969Horan696 ?
# She loves you a lot :)
# See you in Warsaw &lt;3
# Love you &lt;3 x40
# word_1: ['hi', 'bam', 'follow', 'bestfriend', 'love', 'lot', ':)', 'see', 'warsaw', '<3', 'love', '<3', 'x40']
# tweet: #FollowFriday @ACBM_SECEM @DCarsonCPA_NYC @PromosalonsInfo for being top supports in my community this week :)
# word_1: ['followfriday', 'top', 'support', 'commun', 'week', ':)']
# tweet: So True!!  :)  https://t.co/N2ORwrOwhD
# word_1: ['true', ':)']
# tweet: I added a video to a @YouTube playlist http://t.co/09GuSuMrNb im back on twitch and today it going to be league :) - 1 / 3
# word_1: ['ad', 'video', 'playlist', 'im', 'back', 'twitch', 'today', 'go', 'leagu', ':)', '1', '3']
# tweet: @ZarlashtFaisal @Tabinda_Samar Sethi was HIGH ??? :)
# word_1: ['sethi', 'high', ':)']
# tweet: @IAm_Lennox exe skeem saam :)
# word_1: ['exe', 'skeem', 'saam', ':)']
# tweet: These are the people who make me smile. :) @_pumpchkin_ @aka_pump @LilfrenchMsp @_Lishielou908_ http://t.co/iDdtACkA4K
# word_1: ['peopl', 'make', 'smile', ':)']
# tweet: @CoSchedule Thanks for the invite. :)
# word_1: ['thank', 'invit', ':)']
# tweet: @SyedIHusain polite izzat :)
# wese does she trust him? khawateen k sath selfies say to mana kar deya :)
# word_1: ['polit', 'izzat', ':)', 'wese', 'trust', 'khawateen', 'k', 'sath', 'selfi', 'say', 'mana', 'kar', 'deya', ':)']
# tweet: Thank you @MovieTubePW that's my Friday evening sorted :-)
# word_1: ['thank', "that'", 'friday', 'even', 'sort', ':-)']
# tweet: @nova_caneeee you smart :)))
# word_1: ['smart', ':)']
# tweet: @vaalthepal :-) nice hair tbh
# word_1: [':-)', 'nice', 'hair', 'tbh']
# tweet: 5 years :) https://t.co/hJEhDmxuu9
# word_1: ['5', 'year', ':)']
# tweet: jacob will there be a m&amp;g upgrade??:-)
# word_1: ['jacob', 'g', 'upgrad', ':-)']
# tweet: @heydonworks Nice tee man :)
# word_1: ['nice', 'tee', 'man', ':)']
# tweet: Happy family vacation .. :D [pic] — https://t.co/HL0Fw8msf1
# word_1: ['happi', 'famili', 'vacat', '..', ':D', 'pic', '—']
# tweet: some sleep would be nice :-)
# word_1: ['sleep', 'would', 'nice', ':-)']
# tweet: If you're reading this, you're beautiful.
# Like this if you just read this :)
# word_1: ['read', 'beauti', 'like', 'read', ':)']
# tweet: Talking to One person .... Having Two Conversations :))))))))
# word_1: ['talk', 'one', 'person', '...', 'two', 'convers', ':)']
# tweet: skype was fun :-)
# word_1: ['skype', 'fun', ':-)']
# tweet: @SoggyStones should be online :)
# word_1: ['onlin', ':)']
# tweet: ...because it's Friday :D (y) http://t.co/6rA4ZlpjO9
# word_1: ['...', 'friday', ':D']
# tweet: #FollowFriday @CCIFCcanada @AdamEvnmnt @boxcalf1 for being top engaged members in my community this week :)
# word_1: ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']
# tweet: Something to get your #Friday off to a great start :) Have a great day all! #Mclaren #FridayFeeling #TGIF http://t.co/LshgwcXsSv
# word_1: ['someth', 'get', 'friday', 'great', 'start', ':)', 'great', 'day', 'mclaren', 'fridayfeel', 'tgif']
# tweet: @AvinPera  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)
# word_1: ['follow', 'follow', 'u', 'back', ':)']
# tweet: square enix bissmillah ya Allah :)
# word_1: ['squar', 'enix', 'bissmillah', 'ya', 'allah', ':)']
# tweet: @SephtonMark we're training #SocEnt startups at @TobaccoDockLon this week w/ @HelpingB - we'd love to have you drop in if youre arnd town :)
# word_1: ["we'r", 'train', 'socent', 'startup', 'week', 'w', "we'd", 'love', 'drop', 'your', 'arnd', 'town', ':)']
# tweet: @HGVWolfie Basically you piss in a cup and they test it :)))
# word_1: ['basic', 'piss', 'cup', 'test', ':)']
# tweet: @ellenRstewart where are you off to next? :)
# word_1: ['next', ':)']
# tweet: @IonSwitz @notch also, Twitter is terrible for complicated discussions :)
# word_1: ['also', 'twitter', 'terribl', 'complic', 'discuss', ':)']
# tweet: Snapchat me : LynetteLowe #snapchat #kikmenow #snapme #hot #snapchat #amazon #kikmeguys :) http://t.co/kd54m2IAm6
# word_1: ['snapchat', 'lynettelow', 'snapchat', 'kikmenow', 'snapm', 'hot', 'snapchat', 'amazon', 'kikmeguy', ':)']
# tweet: I am not looking forward to a 12 hour shift today :))))))
# word_1: ['look', 'forward', '12', 'hour', 'shift', 'today', ':)']
# tweet: @ely83_ely definately agree that it's a growing sport. Drop me an email with details and we can see what we can do :-)
# word_1: ['defin', 'agre', 'grow', 'sport', 'drop', 'email', 'detail', 'see', ':-)']
# tweet: My last rt is me :)
# word_1: ['last', 'rt', ':)']
# tweet: ...and the Rakyat will keep visiting your blog and reading your writing :) https://t.co/IMRy2BXuzd
# word_1: ['...', 'rakyat', 'keep', 'visit', 'blog', 'read', 'write', ':)']
# tweet: @ryan2390 ever since I mentioned fly fishing the other day I'm getting follows and promoted posts about it lol cyber stalked! :-)
# word_1: ['ever', 'sinc', 'mention', 'fli', 'fish', 'day', "i'm", 'get', 'follow', 'promot', 'post', 'lol', 'cyber', 'stalk', ':-)']
# tweet: @Gurmeetramrahim #OurDaughtersOurPride #mypapamypride Proud of You Papa Coach :)
# word_1: ['ourdaughtersourprid', 'mypapamyprid', 'proud', 'papa', 'coach', ':)']
# tweet: @imarpita it was great talking to you :D
# word_1: ['great', 'talk', ':D']
# tweet: @awaismarwat2011 never see positive kha u could also mention atleast they are going :)
# word_1: ['never', 'see', 'posit', 'kha', 'u', 'could', 'also', 'mention', 'atleast', 'go', ':)']
# tweet: Hi BAM ! @BarsAndMelody
# Can you follow my bestfriend @969Horan696 ?
# She loves you a lot :)
# See you in Warsaw &lt;3
# Love you &lt;3 x39
# word_1: ['hi', 'bam', 'follow', 'bestfriend', 'love', 'lot', ':)', 'see', 'warsaw', '<3', 'love', '<3', 'x39']
# tweet: @_pigglywiggly @Omundson The mango lassi's from Monty's are marvellous :D. Though I suspect that's not what you meant....
# word_1: ['mango', "lassi'", "monty'", 'marvel', ':D', 'though', 'suspect', "that'", 'meant', '...']
# tweet: #FollowFriday @StayfanChemin @CCI_75 @aandreup for being top influencers in my community this week :)
# word_1: ['followfriday', 'top', 'influenc', 'commun', 'week', ':)']
# tweet: @Thakurain_ Haha. Yes. I have 24 hrs. The time has come to touch the Kepler 452b. Chalna hai ?? :D
# word_1: ['haha', 'ye', '24', 'hr', 'time', 'come', 'touch', 'kepler', '452b', 'chalna', 'hai', ':D']
# tweet: @iyah_mohamad  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)
# word_1: ['follow', 'follow', 'u', 'back', ':)']
# tweet: @allygrrdo thankyou pretty! :)
# word_1: ['thankyou', 'pretti', ':)']
# tweet: @PinkPeoniesBlog @helloprettysa definitely the Hazel Food Market in Brooklyn, Pta :) &gt;&gt; http://t.co/ySQkhNDo2B
# word_1: ['definit', 'hazel', 'food', 'market', 'brooklyn', 'pta', ':)']
# tweet: still awake :))))
# word_1: ['still', 'awak', ':)']
# tweet: @joiredve okayy :D
# word_1: ['okayi', ':D']
# tweet: Awww thank you :)  https://t.co/9tSQv2DWVm
# word_1: ['awww', 'thank', ':)']
# tweet: @AR1961 ha! That does not surprise me in the least! Okay but will see doc this afternoon. Yorkshire is splendid though! :) xx
# word_1: ['ha', 'surpris', 'least', 'okay', 'see', 'doc', 'afternoon', 'yorkshir', 'splendid', 'though', ':)', 'xx']
# tweet: @JRTurnerPhoto @davidqueenan @jameslturnbull spam folder: WOW! I have won a huge amount of $ I just need to travel to Nigeria to claim it :)
# word_1: ['spam', 'folder', 'wow', 'huge', 'amount', 'need', 'travel', 'nigeria', 'claim', ':)']
# tweet: @PERKSOFNIALLJH RTed! Good Luck :)
# word_1: ['rted', 'good', 'luck', ':)']
# tweet: My legs hurt so bad :))))))))))))))))))
# word_1: ['leg', 'hurt', 'bad', ':)']
# tweet: @johnny_lopez96 I get mine Saturday :-))))
# word_1: ['get', 'mine', 'saturday', ':-)']
# tweet: @imafaithreyes thaaanks! December puhon. :))
# word_1: ['thaaank', 'decemb', 'puhon', ':)']
# tweet: happinessss~!! :))  https://t.co/slOn63OUeS
# word_1: ['happinesss', ':)']
# tweet: @VaibhavVj78 @PayUmoney True that. Can you change TnC without prior notification? I could have used them last night. :-)
# word_1: ['true', 'chang', 'tnc', 'without', 'prior', 'notif', 'could', 'use', 'last', 'night', ':-)']
# tweet: https://t.co/gYx34VfmkK and I  probably only find this funny at 2:22 am :-)
# word_1: ['probabl', 'find', 'funni', '2:22', ':-)']
# tweet: @aliyaskates @yoshihikomkm Fat cos he probably ate Yuna :D :D :D
# word_1: ['fat', 'co', 'probabl', 'ate', 'yuna', ':D', ':D', ':D']
# tweet: @emmajaneparsons @CuriousMindsNW Have fun in Tameside :))
# word_1: ['fun', 'tamesid', ':)']
# tweet: @hydrcted what :-) did :-) i :-) do :-?
# word_1: [':-)', ':-)', ':-)']
# tweet: @CharmingJedward you´re welcome!! :)
# word_1: ['´', 'welcom', ':)']
# tweet: My Google+ account. :) http://t.co/R8jyDxlQyo
# word_1: ['googl', 'account', ':)']
# tweet: @2SHYMC and they call scousers for everything! Hope you and Zoe are well mate :)
# word_1: ['call', 'scouser', 'everyth', 'hope', 'zoe', 'well', 'mate', ':)']
# tweet: @RachelEvans_28 RIGHT!!!!!! I literally was like maybe u should get people who actually know what they're doing :-) @StudentTrip
# word_1: ['right', 'liter', 'like', 'mayb', 'u', 'get', 'peopl', 'actual', 'know', "they'r", ':-)']
# tweet: || Sameee~
#
# Rest well :) https://t.co/T6ZCo4NxDG
# word_1: ['samee', 'rest', 'well', ':)']
# tweet: @EdgarsLame happy birthday Edgar! I hope you have a good one and keep updating your travel log :)
# word_1: ['happi', 'birthday', 'edgar', 'hope', 'good', 'one', 'keep', 'updat', 'travel', 'log', ':)']
# tweet: Hello :D
# @VikkFollows @Vikkstar123
# word_1: ['hello', ':D']
# tweet: @MarreyJewAna bring Abes :)
# word_1: ['bring', 'abe', ':)']
# tweet: Stats for the day have arrived. 2 new followers and NO unfollowers :) via http://t.co/xxlXs6xYwe.
# word_1: ['stat', 'day', 'arriv', '2', 'new', 'follow', 'unfollow', ':)', 'via']
# tweet: someone talk to me :))
# word_1: ['someon', 'talk', ':)']
# tweet: i will never be the same if we ever meet again :D
# word_1: ['never', 'ever', 'meet', ':D']
# tweet: @BBCSport come on man :D :D
# word_1: ['come', 'man', ':D', ':D']
# tweet: @prettyden15  follow @jnlazts &amp; http://t.co/RCvcYYO0Iq follow u back :)
# word_1: ['follow', 'follow', 'u', 'back', ':)']
# tweet: Hi BAM ! @BarsAndMelody
# Can you follow my bestfriend @969Horan696 ?
# She loves you a lot :)
# See you in Warsaw &lt;3
# Love you &lt;3 x38
# word_1: ['hi', 'bam', 'follow', 'bestfriend', 'love', 'lot', ':)', 'see', 'warsaw', '<3', 'love', '<3', 'x38']
# tweet: @LivelyKaty *sighs dreamily at that pout and those 'come to bath' eyes!* :-) #quacketyquack
# word_1: ['sigh', 'dreamili', 'pout', 'come', 'bath', 'eye', ':-)', 'quacketyquack']
# tweet: @_sunshinehoran_ happy birthday love :)
# word_1: ['happi', 'birthday', 'love', ':)']
# tweet: @Brianscrooks @burwellitltd @manfrotto_tweet Cheers :-)
# word_1: ['cheer', ':-)']
# tweet: Funny how that happened when Phil was here too : )
# word_1: ['funni', 'happen', 'phil']
# tweet: @WMFireDogs I'd call 'em Del &amp; Rodders :) What else!
# word_1: ["i'd", 'call', 'em', 'del', 'rodder', ':)', 'els']
# tweet: @ForkH Hi, may you like play my newest gamejam game, i would be very happy about it :) http://t.co/8J5voDDHcs
# word_1: ['hi', 'may', 'like', 'play', 'newest', 'gamejam', 'game', 'would', 'happi', ':)']
# tweet: This is great! Irish literature is really inaccessible to most of us without Irish :)
# word_1: ['great', 'irish', 'literatur', 'realli', 'inaccess', 'us', 'without', 'irish', ':)']
# tweet: @BhaktisBanter @PallaviRuhail yeah! This is fun :) #FlipkartFashionFriday
# word_1: ['yeah', 'fun', ':)', 'flipkartfashionfriday']
# tweet: Nice music :) Check it out! http://t.co/PEjHsORGrk
# word_1: ['nice', 'music', ':)', 'check']
# tweet: @_xRiya Strange Kareena's Fans Not Knowing Kareena's Fans :)
# word_1: ['strang', "kareena'", 'fan', 'know', "kareena'", 'fan', ':)']
# tweet: Hello :) Get Youth Job Opportunities follow &gt;&gt; @tolajobjobs @e1d4c8e25ec844c
# word_1: ['hello', ':)', 'get', 'youth', 'job', 'opportun', 'follow']
# tweet: better :)
# word_1: ['better', ':)']
# tweet: @ArtForCause Cool. Will look for you there. :)
# word_1: ['cool', 'look', ':)']
# tweet: :)) beautiful http://t.co/F8V3McI39e
# word_1: [':)', 'beauti']
# tweet: I'm playing Brain Dots : ) #BrainDots
# http://t.co/cHl12JvuxN http://t.co/GGgU9PYEjI
# word_1: ["i'm", 'play', 'brain', 'dot', 'braindot']
# tweet: @ScreamQueenLR That's fair enough :) I wouldn't rush back either.
# word_1: ["that'", 'fair', 'enough', ':)', 'rush', 'back', 'either']
# ...
# word_1: ["i'm", 'work', 'next', 'weekend', ':(']
# tweet: @MrMickyD :( not even when u hit me up we had 5
# word_1: [':(', 'even', 'u', 'hit', '5']
# tweet: @JessicaRyanFord I fell asleep :( do you guys wanna come to Starbucks w me lol
# word_1: ['fell', 'asleep', ':(', 'guy', 'wanna', 'come', 'starbuck', 'w', 'lol']
# tweet: @Darlene_Vibares Darlene Followback please :(
# word_1: ['darlen', 'followback', 'pleas', ':(']
# tweet: @JacobAndrade33 @MillerKaapke can we all be gay together at least. Don't leave me out alone :(
# word_1: ['gay', 'togeth', 'least', 'leav', 'alon', ':(']
# tweet: the emoji :((( https://t.co/BFslmBZOAh
# word_1: ['emoji', ':(']
# tweet: Freaking cat won't cuddle with me :-(
# word_1: ['freak', 'cat', 'cuddl', ':-(']
# tweet: @xxKalishaxx @Zoe91x @DeltaGoodrem I see she has a meet and greet tour coming up, but unfortunately she's not coming to Brisbane :(
# word_1: ['see', 'meet', 'greet', 'tour', 'come', 'unfortun', 'come', 'brisban', ':(']
# tweet: @Wilpy1 Too late. :(
# word_1: ['late', ':(']
# tweet: @MerlinHousing hi Merlin, currently waiting a roof repair, and our kitchen is letting in water :( http://t.co/XqaB5F0wB8
# word_1: ['hi', 'merlin', 'current', 'wait', 'roof', 'repair', 'kitchen', 'let', 'water', ':(']
# tweet: @daddyksoo I JUST SAW YOUR MENTION OMG SORRY :-(((((((((
# word_1: ['saw', 'mention', 'omg', 'sorri', ':-(']
# tweet: @WeeklyChris I'm sorry sweetie :( No one deserves that.
# word_1: ["i'm", 'sorri', 'sweeti', ':(', 'one', 'deserv']
# tweet: nawwwee i miss hyperbullies. like tong 3rd yr nga seatmates rajud mi mag barkada :(
# word_1: ['nawwwe', 'miss', 'hyperbulli', 'like', 'tong', '3rd', 'yr', 'nga', 'seatmat', 'rajud', 'mi', 'mag', 'barkada', ':(']
# tweet: @Thisbummarcus I'll miss you buddy :(
# word_1: ["i'll", 'miss', 'buddi', ':(']
# tweet: @baexsuze ores! :(
# word_1: ['ore', ':(']
# tweet: So sick :(
# word_1: ['sick', ':(']
# tweet: Not looking promising for our evening at the cricket, is it @jaybutcher @MrTomBaker? :( http://t.co/9U5yeDfqqg
# word_1: ['look', 'promis', 'even', 'cricket', ':(']
# tweet: I only sleep good when I'm at kaylas :(
# word_1: ['sleep', 'good', "i'm", 'kayla', ':(']
# tweet: I miss everyone so much. Feel like I've not seen them in so long :(
# word_1: ['miss', 'everyon', 'much', 'feel', 'like', "i'v", 'seen', 'long', ':(']
# tweet: @chonchonnie I have yet to finish it! I'm still on season 7. :(
# word_1: ['yet', 'finish', "i'm", 'still', 'season', '7', ':(']
# tweet: Looking for fun? SNAPCHAT - ericavan18 #snapchat #snapchatme #likeforlike #interracial #model #repost #sexo :( http://t.co/X6O6vJmGac
# word_1: ['look', 'fun', 'snapchat', 'ericavan', '18', 'snapchat', 'snapchatm', 'likeforlik', 'interraci', 'model', 'repost', 'sexo', ':(']
# tweet: Again not feeling well :(
# word_1: ['feel', 'well', ':(']
# tweet: WHY..... :(( not that I hate jong or dongwoo is just that all the photocards I've been getting is WH, DW &amp; SJ http://t.co/zEQNiFVHUT
# word_1: ['...', ':(', 'hate', 'jong', 'dongwoo', 'photocard', "i'v", 'get', 'wh', 'dw', 'sj']
# tweet: May brain tumor si Vivian :( #MMSMalubhangSakit
# word_1: ['may', 'brain', 'tumor', 'si', 'vivian', ':(', 'mmsmalubhangsakit']
# tweet: Is everyone talking about rat boy today bc :(
# word_1: ['everyon', 'talk', 'rat', 'boy', 'today', 'bc', ':(']
# tweet: My feet hurt :(
# word_1: ['feet', 'hurt', ':(']
# tweet: @frkntrd oh man schade :(
# word_1: ['oh', 'man', 'schade', ':(']
# tweet: @wajiyaamjad ohh :( the first year will be a bit tiring but things get better after that!
# word_1: ['ohh', ':(', 'first', 'year', 'bit', 'tire', 'thing', 'get', 'better']
# tweet: @zaynmalik zayn come back to 1D already. :(
# word_1: ['zayn', 'come', 'back', '1d', 'alreadi', ':(']
# tweet: I'm freezing :(
# word_1: ["i'm", 'freez', ':(']
# tweet: I wanted the shoes FOR my holiday, shipping should take 4-5 days so it should have arrived TODAY, but it's not even on its way @DCSHOESUK :(
# word_1: ['want', 'shoe', 'holiday', 'ship', 'take', '4-5', 'day', 'arriv', 'today', 'even', 'way', ':(']
# tweet: @BeaMiller u didn't follow me :((
# word_1: ['u', 'follow', ':(']
# tweet: @OhPrincessSaRaH I didn't see it so you must not of... been trying to think for a day what it could be...I've think I just figured it out :(
# word_1: ['see', 'must', '...', 'tri', 'think', 'day', 'could', '...', "i'v", 'think', 'figur', ':(']
# tweet: My SNAPCHAT - JillCruz18 #snapchat #kiksexting #likeforlike #hornykik #lgbt #music #camsex :( http://t.co/lk77WR8Rrb
# word_1: ['snapchat', 'jillcruz', '18', 'snapchat', 'kiksext', 'likeforlik', 'hornykik', 'lgbt', 'music', 'camsex', ':(']
# tweet: I feel like I'm the only person in Ireland not going to see @edsheeran in Croke park :(
# word_1: ['feel', 'like', "i'm", 'person', 'ireland', 'go', 'see', 'croke', 'park', ':(']
# tweet: @juonghwa sore qt :(
# word_1: ['sore', 'qt', ':(']
# tweet: @sallydunne @laurentierneyy_ not til 19th of sept cos that's when bills start and full rent :(
# word_1: ['til', '19th', 'sept', 'co', "that'", 'bill', 'start', 'full', 'rent', ':(']
# tweet: ok this whole time I've been tossing &amp; turning in my bed trying to go to sleep but I just can't :(
# word_1: ['ok', 'whole', 'time', "i'v", 'toss', 'turn', 'bed', 'tri', 'go', 'sleep', "can't", ':(']
# tweet: Showed up to open shop, but my co-worker is MIA :( Hopefully they arrive soon, I'm starving.
# word_1: ['show', 'open', 'shop', 'co-work', 'mia', ':(', 'hope', 'arriv', 'soon', "i'm", 'starv']
# tweet: @antichankai yup!! i always order there anyways 😂 i hope it pushes through :((
# word_1: ['yup', 'alway', 'order', 'anyway', '😂', 'hope', 'push', ':(']
# tweet: @chaisooyoung dare :(
# word_1: ['dare', ':(']
# tweet: Unsettled weather is the trend for the next few days. Sun this morning. Showers this afternoon. GH is 18C. Mixed bag for the weekend :-(.
# word_1: ['unsettl', 'weather', 'trend', 'next', 'day', 'sun', 'morn', 'shower', 'afternoon', 'gh', '18c', 'mix', 'bag', 'weekend', ':-(']
# tweet: @mzhrkiks why? but you'll get sick :(
# word_1: ['get', 'sick', ':(']
# tweet: @jungsilhoon two days before my birthday :(
# word_1: ['two', 'day', 'birthday', ':(']
# tweet: IM LISTENING TO EVERYTHING ABOUT YOU :((
# word_1: ['im', 'listen', 'everyth', ':(']
# tweet: @chuchuxiu shit rlly?:( i heard hamsters eat each other thats pretty fucked up hamsters r weird
# word_1: ['shit', 'rlli', ':(', 'heard', 'hamster', 'eat', 'that', 'pretti', 'fuck', 'hamster', 'r', 'weird']
# tweet: just wanna see ed sheeran preform tonight :(
# word_1: ['wanna', 'see', 'ed', 'sheeran', 'preform', 'tonight', ':(']
# tweet: @demongrrl51 some peanut has probably crashed :( .. after all you've seen how they drive on the monash ...?
# word_1: ['peanut', 'probabl', 'crash', ':(', '..', 'seen', 'drive', 'monash', '...']
# tweet: @Astiera01 @KapitaineRose @Madtloves What?P..... :(
# word_1: ['p', '...', ':(']
# tweet: When you cant find a gift so you end up using the money for starbucks :(((((
# word_1: ['cant', 'find', 'gift', 'end', 'use', 'money', 'starbuck', ':(']
# tweet: @modern_combat I hope the hitmarker glitch is fixed soon :(
# word_1: ['hope', 'hitmark', 'glitch', 'fix', 'soon', ':(']
# tweet: @SafaaAzadMalik_ okay, safaa, please follow me :( I love you
# word_1: ['okay', 'safaa', 'pleas', 'follow', ':(', 'love']
# tweet: Guess who's missed Selena's tweets for fans?:(
# word_1: ['guess', "who'", 'miss', "selena'", 'tweet', 'fan', ':(']
# tweet: My summer sleep schedule is back :(((
# word_1: ['summer', 'sleep', 'schedul', 'back', ':(']
# tweet: my eyes want to sleep but the rest of me doesn't. :( This is bad.
# word_1: ['eye', 'want', 'sleep', 'rest', ':(', 'bad']
# tweet: @unclutching :( u okay
# word_1: [':(', 'u', 'okay']
# tweet: @ZahraMubeen ye galat hai tum ne mjhe ab non respected lrka bna dia, itna rude word use kia hai ke ab mere bhook hi khatam ho jai hai :(
# word_1: ['ye', 'galat', 'hai', 'tum', 'ne', 'mjhe', 'ab', 'non', 'respect', 'lrka', 'bna', 'dia', 'itna', 'rude', 'word', 'use', 'kia', 'hai', 'ke', 'ab', 'mere', 'bhook', 'hi', 'khatam', 'ho', 'jai', 'hai', ':(']
# tweet: can anyone give me money for the train so that i can see @littlemix today?! :(
# word_1: ['anyon', 'give', 'money', 'train', 'see', 'today', ':(']
# tweet: Not been to the gym all week, so I need a BIG personal push today to get me there tonight....i've been making excuses to myself. #Lazy :-(
# word_1: ['gym', 'week', 'need', 'big', 'person', 'push', 'today', 'get', 'tonight', '...', "i'v", 'make', 'excus', 'lazi', ':-(']
# tweet: annoying :((((((((
# word_1: ['annoy', ':(']
# tweet: @carlyraejepsen you ain't gonna follow me?:(
# word_1: ["ain't", 'gonna', 'follow', ':(']
# tweet: This Social Experiment, made me cry. :( http://t.co/4EiBxJPE9E
# word_1: ['social', 'experi', 'made', 'cri', ':(']
# tweet: @ayoo_gerry i miss you :-(
# word_1: ['miss', ':-(']
# tweet: afterschool cant have a comeback even tho they want to coz they have no money :(((
# word_1: ['afterschool', 'cant', 'comeback', 'even', 'tho', 'want', 'coz', 'money', ':(']
# tweet: Please Pray for my friend Bilal Ashraf his in ICU :( http://t.co/oUtwk8ON6O
# word_1: ['pleas', 'pray', 'friend', 'bilal', 'ashraf', 'icu', ':(']
# tweet: @qureshi_ruksar thankssss.     :(
# word_1: ['thanksss', ':(']
# tweet: I MISS SO MANY PEOPLE :-(
# word_1: ['miss', 'mani', 'peopl', ':-(']
# tweet: @karisshackett01 @MarzJackson won't be long for us all :(
# word_1: ['long', 'us', ':(']
# tweet: @taesprout ah im sorry :-( when was it
# word_1: ['ah', 'im', 'sorri', ':-(']
# tweet: Annnd, now not going to Winchester {:-(
# word_1: ['annnd', 'go', 'winchest', '{:']
# tweet: Its been 1 year now, Since he texted me this... I miss everything. But now, I know he will never be with me again :( http://t.co/lzr8hSb0Q5
# word_1: ['1', 'year', 'sinc', 'text', '...', 'miss', 'everyth', 'know', 'never', ':(']
# tweet: @JustTakeMeHome_ aw I used the same photo :(
# word_1: ['aw', 'use', 'photo', ':(']
# tweet: Exactly :( http://t.co/LJRY4TTlRe
# word_1: ['exactli', ':(']
# tweet: @grindmegrande I always make so much effort to talk to you and all I get is like one or two tweets or DMs all day... like really? come on :(
# word_1: ['alway', 'make', 'much', 'effort', 'talk', 'get', 'like', 'one', 'two', 'tweet', 'dm', 'day', '...', 'like', 'realli', 'come', ':(']
# tweet: @Penguin_porter that's awful :(
# word_1: ["that'", 'aw', ':(']
# tweet: @wonwooo17 /grepe grepein/ :(
# word_1: ['grepe', 'grepein', ':(']
# tweet: I don't want Panem to end :( I just LOVE the books and the movies
# word_1: ['want', 'panem', 'end', ':(', 'love', 'book', 'movi']
# tweet: @sophiabxsh no Idk if I wanna watch the episode now :(
# word_1: ['idk', 'wanna', 'watch', 'episod', ':(']
# tweet: @_Jazdorothy why my lover :( you going zoo?
# word_1: ['lover', ':(', 'go', 'zoo']
# tweet: @SweetieBiebs baby &gt; boyfriend &gt; bitch??? I don't know how to complete it :(
# word_1: ['babi', 'boyfriend', 'bitch', 'know', 'complet', ':(']
# tweet: All ice cream vans are busy :( Maybe later...  #UberIceCream http://t.co/t6GAoKfAp1
# word_1: ['ice', 'cream', 'van', 'busi', ':(', 'mayb', 'later', '...', 'ubericecream']
# tweet: @lifelesscurves hopefully not :( but sulli was like that too.........well, there was injured amber too, but she's still there haha sigh f(x)
# word_1: ['hope', ':(', 'sulli', 'like', '...', 'well', 'injur', 'amber', 'still', 'haha', 'sigh', 'f', 'x']
# tweet: @darrenlewington Ouch :( What's happened to make you say this Darren? Is there anything we can help you with from here?
# word_1: ['ouch', ':(', "what'", 'happen', 'make', 'say', 'darren', 'anyth', 'help']
# tweet: not even sleepy :(
# word_1: ['even', 'sleepi', ':(']
# tweet: only CPM has condemned it, rest all political parties are quiet :(
# word_1: ['cpm', 'condemn', 'rest', 'polit', 'parti', 'quiet', ':(']
# tweet: When you realise that 2/3 of your big summer plans have been and gone :( :( :( next up is PARIS ✔️
# word_1: ['realis', '2/3', 'big', 'summer', 'plan', 'gone', ':(', ':(', ':(', 'next', 'pari', '✔', '️']
# tweet: Oops... a server error occurred and your email was not sent. :( :(
# word_1: ['oop', '...', 'server', 'error', 'occur', 'email', 'sent', ':(', ':(']
# tweet: @ajtszxc miss you too :(
# word_1: ['miss', ':(']
# tweet: @Insanomania They do... Their mentality doesn't :(
# word_1: ['...', 'mental', ':(']
# tweet: @hosongjun noooo :( it was too late d. Nvm d lah
# word_1: ['nooo', ':(', 'late', 'nvm', 'lah']
# tweet: everything reminds me of u :-(
# word_1: ['everyth', 'remind', 'u', ':-(']
# tweet: no date yet :(  https://t.co/Tu9R2CfSyx
# word_1: ['date', 'yet', ':(']
# tweet: feel like eating unagi out of a sudden :( https://t.co/cI5FPi66co
# word_1: ['feel', 'like', 'eat', 'unagi', 'sudden', ':(']
# tweet: @SarahRashadd straight 7elw :( at least mesh beyt3a2ad
# word_1: ['straight', '7elw', ':(', 'least', 'mesh', 'beyt', '3a2ad']
# tweet: @kaiality too late now :(
# word_1: ['late', ':(']
# tweet: @Mvusi_ lol I'm still very fluent and people say I sound white :( but varsity ruined me. Sengenza typos and I use some words out of context.
# word_1: ['lol', "i'm", 'still', 'fluent', 'peopl', 'say', 'sound', 'white', ':(', 'varsiti', 'ruin', 'sengenza', 'typo', 'use', 'word', 'context']
# tweet: @ErwanLeCorre is there MovNat in Belgium? First search yields nothing... :-( #NBHeroes
# word_1: ['movnat', 'belgium', 'first', 'search', 'yield', 'noth', '...', ':-(', 'nbhero']
# tweet: @RocksteadyGames Tried doing it from my xbox, but it seems it doesn't work...:( it'd make a killer background.
# word_1: ['tri', 'xbox', 'seem', 'work', '...', ':(', "it'd", 'make', 'killer', 'background']
# tweet: Looking for fun? KIK : agover73 #kik #kikgirl #hornykik #makeup #orgasm #brasileirao #sexdate :( http://t.co/PDxVjLdhi7
# word_1: ['look', 'fun', 'kik', 'agov', '73', 'kik', 'kikgirl', 'hornykik', 'makeup', 'orgasm', 'brasileirao', 'sexdat', ':(']
# tweet: Watching abusive relationship videos is so fucking hard. I'm trying not to cry but it's like... :(
# word_1: ['watch', 'abus', 'relationship', 'video', 'fuck', 'hard', "i'm", 'tri', 'cri', 'like', '...', ':(']
# tweet: @hitgal_hashmi me also good.. But why are u not present here?? Have not seen u long time :(
# word_1: ['also', 'good', '..', 'u', 'present', 'seen', 'u', 'long', 'time', ':(']
# tweet: I like u sm :-(
# word_1: ['like', 'u', 'sm', ':-(']
# tweet: I'm so inactive. I wanna cry! :(
# word_1: ["i'm", 'inact', 'wanna', 'cri', ':(']
# tweet: Looking for fun? SNAPCHAT : JillCruz18 #snapchat #kikhorny #talk #teens #oralsex #batalladelosgallos #kikhorny :( http://t.co/OjCdZIHpuz
# word_1: ['look', 'fun', 'snapchat', 'jillcruz', '18', 'snapchat', 'kikhorni', 'talk', 'teen', 'oralsex', 'batalladelosgallo', 'kikhorni', ':(']
# tweet: @GODDAMMlT SRSLY FUCK U UNFOLLOWER HOPE UR FUTURE CHILD UNPARENTS U &gt;:-(
# word_1: ['srsli', 'fuck', 'u', 'unfollow', 'hope', 'ur', 'futur', 'child', 'unpar', 'u', '>:-(']
# tweet: Ah i honestly love my dad so much I'm slightly upset that I'm not seeing him on my birthday :(
# word_1: ['ah', 'honestli', 'love', 'dad', 'much', "i'm", 'slightli', 'upset', "i'm", 'see', 'birthday', ':(']
# tweet: @soarcasm Bianca
#
# Ur one and only bun : (
# word_1: ['bianca', 'ur', 'one', 'bun']
# tweet: you already knew i couldn't stand to let people dislike me :(( it's burdensome and i want totally clear it as soon as possible
# word_1: ['alreadi', 'knew', 'stand', 'let', 'peopl', 'dislik', ':(', 'burdensom', 'want', 'total', 'clear', 'soon', 'possibl']
# tweet: @aquazzSky same here omg I miss them so badly :(((
# word_1: ['omg', 'miss', 'badli', ':(']
# tweet: Amelia didnt stalk my twitter :(
# word_1: ['amelia', 'didnt', 'stalk', 'twitter', ':(']
# tweet: oh, i missed the broadcast. : (
# word_1: ['oh', 'miss', 'broadcast']
# tweet: i really can't stream on melon i feel useless :-(
# word_1: ['realli', "can't", 'stream', 'melon', 'feel', 'useless', ':-(']
# tweet: I need to stop looking at old soccer pictures :(
# word_1: ['need', 'stop', 'look', 'old', 'soccer', 'pictur', ':(']
# tweet: Got an interview for the job that I want but they rang me Tuesday for the interview on Thursday but in on holiday :(
# word_1: ['got', 'interview', 'job', 'want', 'rang', 'tuesday', 'interview', 'thursday', 'holiday', ':(']
# The cost after training is 0.22522315.
# The resulting vector of weights is [6e-08, 0.00053818, -0.0005583]

# %%
X
# Out:
# array([[1.000e+00, 3.133e+03, 6.100e+01],
#        [1.000e+00, 3.705e+03, 4.440e+02],
#        [1.000e+00, 3.119e+03, 1.160e+02],
#        ...,
#        [1.000e+00, 1.440e+02, 7.930e+02],
#        [1.000e+00, 2.070e+02, 3.902e+03],
#        [1.000e+00, 1.910e+02, 3.986e+03]])

# %% [markdown]
# **Expected Output**:
#
# ```
# The cost after training is 0.22522315.
# The resulting vector of weights is [6e-08, 0.00053818, -0.0005583]
# ```

# %% [markdown]
# # Part 4: Test your logistic regression
#
# It is time for you to test your logistic regression function on some new input that your model has not seen before.
#
# #### Instructions: Write `predict_tweet`
# Predict whether a tweet is positive or negative.
#
# * Given a tweet, process it, then extract the features.
# * Apply the model's learned weights on the features to get the logits.
# * Apply the sigmoid to the logits to get the prediction (a value between 0 and 1).
#
# $$y_{pred} = sigmoid(\mathbf{x} \cdot \theta)$$

# %%
# UNQ_C4 GRADED FUNCTION: predict_tweet
def predict_tweet(tweet, freqs, theta):
    '''
    Input: 
        tweet: a string
        freqs: a dictionary corresponding to the frequencies of each tuple (word, label)
        theta: (3,1) vector of weights
    Output: 
        y_pred: the probability of a tweet being positive or negative
    '''
    ### START CODE HERE ###
    
    # extract the features of the tweet and store it into x
    x = extract_features(tweet, freqs)
    
    # make the prediction using x and theta
    y_pred = sigmoid(np.dot(x, theta))
    
    ### END CODE HERE ###
    
    return y_pred

# %%
# Run this cell to test your function
for tweet in ['I am happy', 'I am bad', 'this movie should have been great.', 'great', 'great great', 'great great great', 'great great great great']:
    print( '%s -> %f' % (tweet, predict_tweet(tweet, freqs, theta)))
# Out:
# I am happy -> 0.519275
# I am bad -> 0.494347
# this movie should have been great. -> 0.515979
# great -> 0.516065
# great great -> 0.532096
# great great great -> 0.548062
# great great great great -> 0.563929

# %% [markdown]
# **Expected Output**:
# ```
# I am happy -> 0.519275
# I am bad -> 0.494347
# this movie should have been great. -> 0.515979
# great -> 0.516065
# great great -> 0.532096
# great great great -> 0.548062
# great great great great -> 0.563929
# ```

# %%
# Feel free to check the sentiment of your own tweet below
my_tweet = 'I am learning :)'
predict_tweet(my_tweet, freqs, theta)
# Out:
# array([[0.83110307]])

# %%
# Test your function
w1_unittest.test_predict_tweet(predict_tweet, freqs, theta)
# Out:
#  All tests passed

# %% [markdown]
# ## Check performance using the test set
# After training your model using the training set above, check how your model might perform on real, unseen data, by testing it against the test set.
#
# #### Instructions: Implement `test_logistic_regression`
# * Given the test data and the weights of your trained model, calculate the accuracy of your logistic regression model.
# * Use your 'predict_tweet' function to make predictions on each tweet in the test set.
# * If the prediction is > 0.5, set the model's classification 'y_hat' to 1, otherwise set the model's classification 'y_hat' to 0.
# * A prediction is accurate when the y_hat equals the test_y.  Sum up all the instances when they are equal and divide by m.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>Use np.asarray() to convert a list to a numpy array</li>
#     <li>Use numpy.squeeze() to make an (m,1) dimensional array into an (m,) array </li>
# </ul>
# </p>

# %%
# UNQ_C5 GRADED FUNCTION: test_logistic_regression
def test_logistic_regression(test_x, test_y, freqs, theta, predict_tweet=predict_tweet):
    """
    Input: 
        test_x: a list of tweets
        test_y: (m, 1) vector with the corresponding labels for the list of tweets
        freqs: a dictionary with the frequency of each pair (or tuple)
        theta: weight vector of dimension (3, 1)
    Output: 
        accuracy: (# of tweets classified correctly) / (total # of tweets)
    """
    
    ### START CODE HERE ###
    
    # the list for storing predictions
    y_hat = []
    
    for tweet in test_x:
        # get the label prediction for the tweet
        y_pred = predict_tweet(tweet, freqs, theta)
        
        if y_pred > 0.5:
            # append 1.0 to the list
            y_hat.append(1.0)
        else:
            # append 0 to the list
            y_hat.append(0.0)

    # With the above implementation, y_hat is a list, but test_y is (m,1) array
    # convert both to one-dimensional arrays in order to compare them using the '==' operator
    accuracy = (y_hat==np.squeeze(test_y)).sum()/len(test_y)
    ### END CODE HERE ###
    
    return accuracy

# %%
tmp_accuracy = test_logistic_regression(test_x, test_y, freqs, theta)
print(f"Logistic regression model's accuracy = {tmp_accuracy:.4f}")
# Out:
# Logistic regression model's accuracy = 0.9950

# %% [markdown]
# #### Expected Output:
# ```0.9950```
# Pretty good!

# %%
# Test your function
w1_unittest.unittest_test_logistic_regression(test_logistic_regression, freqs, theta)
# Out:
#  All tests passed

# %% [markdown]
# # Part 5: Error Analysis
#
# In this part you will see some tweets that your model misclassified. Why do you think the misclassifications happened? Specifically what kind of tweets does your model misclassify?

# %%
# Some error analysis done for you
print('Label Predicted Tweet')
for x,y in zip(test_x,test_y):
    y_hat = predict_tweet(x, freqs, theta)

    if np.abs(y - (y_hat > 0.5)) > 0:
        print('THE TWEET IS:', x)
        print('THE PROCESSED TWEET IS:', process_tweet(x))
        print('%d\t%0.8f\t%s' % (y, y_hat, ' '.join(process_tweet(x)).encode('ascii', 'ignore')))
# Out:
# Label Predicted Tweet
# THE TWEET IS: @MarkBreech Not sure it would be good thing 4 my bottom daring 2 say 2 Miss B but Im gonna be so stubborn on mouth soaping ! #NotHavingit :p
# THE PROCESSED TWEET IS: ['sure', 'would', 'good', 'thing', '4', 'bottom', 'dare', '2', 'say', '2', 'miss', 'b', 'im', 'gonna', 'stubborn', 'mouth', 'soap', 'nothavingit', ':p']
# 1	0.48901497	b'sure would good thing 4 bottom dare 2 say 2 miss b im gonna stubborn mouth soap nothavingit :p'
# THE TWEET IS: I'm playing Brain Dots : ) #BrainDots
# http://t.co/UGQzOx0huu
# THE PROCESSED TWEET IS: ["i'm", 'play', 'brain', 'dot', 'braindot']
# 1	0.48418949	b"i'm play brain dot braindot"
# THE TWEET IS: I'm playing Brain Dots : ) #BrainDots http://t.co/aOKldo3GMj http://t.co/xWCM9qyRG5
# THE PROCESSED TWEET IS: ["i'm", 'play', 'brain', 'dot', 'braindot']
# 1	0.48418949	b"i'm play brain dot braindot"
# THE TWEET IS: I'm playing Brain Dots : ) #BrainDots http://t.co/R2JBO8iNww http://t.co/ow5BBwdEMY
# THE PROCESSED TWEET IS: ["i'm", 'play', 'brain', 'dot', 'braindot']
# 1	0.48418949	b"i'm play brain dot braindot"
# THE TWEET IS: off to the park to get some sunlight : )
# THE PROCESSED TWEET IS: ['park', 'get', 'sunlight']
# 1	0.49636374	b'park get sunlight'
# THE TWEET IS: @msarosh Uff Itna Miss karhy thy ap :p
# THE PROCESSED TWEET IS: ['uff', 'itna', 'miss', 'karhi', 'thi', 'ap', ':p']
# 1	0.48237069	b'uff itna miss karhi thi ap :p'
# THE TWEET IS: @phenomyoutube u probs had more fun with david than me : (
# THE PROCESSED TWEET IS: ['u', 'prob', 'fun', 'david']
# 0	0.50988239	b'u prob fun david'
# THE TWEET IS: pats jay : (
# THE PROCESSED TWEET IS: ['pat', 'jay']
# 0	0.50040365	b'pat jay'
# THE TWEET IS: my beloved grandmother : ( https://t.co/wt4oXq5xCf
# THE PROCESSED TWEET IS: ['belov', 'grandmoth']
# 0	0.50000002	b'belov grandmoth'
# THE TWEET IS: Sr. Financial Analyst - Expedia, Inc.: (#Bellevue, WA) http://t.co/ktknMhvwCI #Finance #ExpediaJobs #Job #Jobs #Hiring
# THE PROCESSED TWEET IS: ['sr', 'financi', 'analyst', 'expedia', 'inc', 'bellevu', 'wa', 'financ', 'expediajob', 'job', 'job', 'hire']
# 0	0.50648681	b'sr financi analyst expedia inc bellevu wa financ expediajob job job hire'

# %% [markdown]
# Later in this specialization, we will see how we can use deeplearning to improve the prediction performance.

# %% [markdown]
# # Part 6: Predict with your own tweet

# %%
# Feel free to change the tweet below
my_tweet = 'This is a ridiculously bright movie. The plot was terrible and I was sad until the ending!'
print(process_tweet(my_tweet))
y_hat = predict_tweet(my_tweet, freqs, theta)
print(y_hat)
if y_hat > 0.5:
    print('Positive sentiment')
else: 
    print('Negative sentiment')
# Out:
# ['ridicul', 'bright', 'movi', 'plot', 'terribl', 'sad', 'end']
# [[0.48125423]]
# Negative sentiment
